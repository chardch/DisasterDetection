# %%
import geopandas as gpd
import os
import pandas as pd
import rasterio
import shapely

# Keep CRS consistent, always use espg:4326
CRS = {'init':'epsg:4326'}

# %%
# Geojson file with building polygons. Obtained from OSM via Geofabrik (http://download.geofabrik.de/)
buildings = gpd.read_file('/Users/apando/school/cs230/project/datasets/hurricane_maria/ground_truth/buildings/buildings.geojson')

# %%
print(len(buildings))
buildings.head()
# Out:
# 1498316
#                                             geometry
# 0  POLYGON ((-66.04452809999999 18.4021147, -66.0...
# 1  POLYGON ((-66.0463973 18.4021623, -66.0463973 ...
# 2  POLYGON ((-66.0483139 18.4023847, -66.0483112 ...
# 3  POLYGON ((-66.0485137 18.4023866, -66.04864739...
# 4  POLYGON ((-66.0470406 18.4073665, -66.0470528 ...

# %%
# Directory containing *.gdb files from FEMA with damage points from visual assessment 
# (https://data.femadata.com/NationalDisasters/HurricaneMaria/Data/DamageAssessments/)
damage_dir = '/Users/apando/school/cs230/project/datasets/hurricane_maria/ground_truth/damage'
damage_list = []
for gdb_dir in os.listdir(damage_dir):
    if gdb_dir.endswith('.gdb'):
        dmg = gpd.read_file(damage_dir + "/" + gdb_dir)
        print("Appending {} damage points".format(len(dmg)))
        damage_list.append(dmg)
        
damage_pts = gpd.GeoDataFrame(pd.concat(damage_list, ignore_index=True), crs=CRS)

print("Added {0} damage points from {1} datasets".format(len(damage_pts), len(damage_list)))
# Out:
# Appending 72640 damage points
# Appending 12837 damage points
# Appending 9264 damage points
# Appending 28028 damage points
# Appending 18728 damage points
# Appending 35357 damage points
# Appending 30788 damage points
# Appending 17529 damage points
# Appending 53664 damage points
# Appending 14314 damage points
# Appending 50116 damage points
# Appending 46190 damage points
# Appending 9672 damage points
# Added 399127 damage points from 13 datasets

# %%
damage_pts = damage_pts.drop_duplicates(['LONGITUDE', 'LATITUDE'])
print(len(damage_pts))
# Out:
# 126221

# %%
print(damage_pts['DMG_LEVEL'].unique())
print(damage_pts['DMG_TYPE'].unique())
# Out:
# ['MAJ' 'MIN' 'DES' 'AFF']
# ['FL' 'WI' ' ']

# %%
# Map damage points to buildings. For our experiment, we will not include 
# damage points that don't have a building associated with them, as we are
# specifically looking for damaged buildings.

# Right join to keep the building polygons
buildings_dmg_points = gpd.sjoin(damage_pts, buildings, how="right", op="within")

buildings_dmg_points.head()
# Out:
#              index_left DMG_LEVEL DMG_TYPE ASMT_TYPE IN_DEPTH WIND_SPEED  \
# index_right
# 18              11457.0       MIN       FL       MOD     None        UNK
# 66              84884.0       AFF       WI        RS     None        UNK
# 68              80290.0       AFF       WI        RS     None        UNK
# 74             172600.0       AFF       WI        RS     None        UNK
# 76              80934.0       AFF       WI        RS     None        UNK
#
#               PGA ACCESS COUNTY STATE  ... IMG_DATE       EVENT_NAME  \
# index_right                            ...
# 18           None    UNK               ...     None  Hurricane Maria
# 66           None    UNK               ...     None  Hurricane Maria
# 68           None    UNK               ...     None  Hurricane Maria
# 74           None    UNK               ...     None  Hurricane Maria
# 76           None    UNK               ...     None  Hurricane Maria
#
#             EVENT_DATE SOURCE DIS_NUMBER COMMENTS  LONGITUDE   LATITUDE  USNG  \
# index_right
# 18                None   FEMA       None     None -66.672340  18.481077  None
# 66                None   FEMA       None     None -66.019852  18.248766  None
# 68                None   FEMA       None     None -66.125748  18.440516  None
# 74                None   FEMA       None     None -65.974953  18.391367  None
# 76                None   FEMA       None     None -66.106323  18.466669  None
#
#                                                       geometry
# index_right
# 18           POLYGON ((-66.6722827 18.4811393, -66.6722821 ...
# 66           POLYGON ((-66.0213978 18.2498477, -66.0201426 ...
# 68           POLYGON ((-66.1261362 18.4406596, -66.1257715 ...
# 74           POLYGON ((-65.9747436 18.3912258, -65.9745781 ...
# 76           POLYGON ((-66.10649340000001 18.4665909, -66.1...
#
# [5 rows x 22 columns]

# %%
print(len(buildings_dmg_points))
# Out:
# 1502705

# %%
# Split damaged and non-damaged buildings
damaged_buildings = buildings_dmg_points[pd.notnull(buildings_dmg_points['index_left'])]
non_damaged_buildings = buildings_dmg_points[~pd.notnull(buildings_dmg_points['index_left'])]

print("Found {0} damaged buildings and {1} non-damaged buildings".format(len(damaged_buildings), len(non_damaged_buildings)))
# Out:
# Found 92361 damaged buildings and 1410344 non-damaged buildings

# %%
damaged_buildings['is_damaged'] = True
non_damaged_buildings['is_damaged'] = False
all_buildings = pd.concat([damaged_buildings, non_damaged_buildings], ignore_index=True)

print("{} total buildings".format(len(all_buildings)))
# Out:
# /Users/apando/miniconda3/envs/disaster-detection/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# 1502705 total buildings
# /Users/apando/miniconda3/envs/disaster-detection/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Find the NOAA tiles each these buildings is in.

# First, map tiles to their bounding box polygons.
# Root dir is the high-level directory where tiles are located.
tile_coords_map = pd.DataFrame(columns=['tile_filename', 'tile_bbox'])
tile_coords_list = []
num_tiles = 0
for curr_dir, _, file_list in os.walk('/Users/apando/school/cs230/project/datasets/hurricane_maria/post_event/noaa/tiles'):
    for fname in file_list:
        # Do not include pyramids, which are stored in a /1 dir with in the tiles/ directory.
        if not curr_dir.endswith('1') and fname.endswith(".tif"):
            num_tiles += 1
            tile_loc = curr_dir + "/" + fname
            
            # Find the bounding box of the tile to form a mapping DataFrame
            tile = rasterio.open(tile_loc)
            tile_coords_list.append((tile_loc, 
                                     (tile.bounds.left, tile.bounds.bottom, tile.bounds.right, tile.bounds.top)))
            
            if num_tiles % 1000 == 0:
                print("Processed {0} tiles... curr tile: {1}".format(num_tiles, fname))

tile_coords_map_cols = list(map(list, zip(*tile_coords_list)))
tile_coords_map = gpd.GeoDataFrame({'tile_filename': tile_coords_map_cols[0], 
                                    'tile_bbox': list(map(lambda x: shapely.geometry.box(*x), 
                                                          tile_coords_map_cols[1]))},
                                  geometry='tile_bbox', crs=CRS)

print("Mapped {} tiles to bboxes".format(len(tile_coords_map)))
# Out:
# Processed 1000 tiles... curr tile: 20170924bC0660300w182700n_16_08.tif
# Processed 2000 tiles... curr tile: 20170924bC0663430w182830n_03_02.tif
# Processed 3000 tiles... curr tile: 20170926aC0661200w175830n_16_13.tif
# Processed 4000 tiles... curr tile: 20170924bC0663000w182700n_14_03.tif
# Processed 5000 tiles... curr tile: 20170924bC0663130w182700n_03_08.tif
# Processed 6000 tiles... curr tile: 20170924bC0660300w182700n_13_07.tif
# Processed 7000 tiles... curr tile: 20170926aC0663600w180000n_07_15.tif
# Processed 8000 tiles... curr tile: 20170924aC0654930w180430n_02_08.tif
# Processed 9000 tiles... curr tile: 20170924aC0653130w180600n_13_10.tif
# Processed 10000 tiles... curr tile: 20170926aC0663900w180000n_11_05.tif
# Processed 11000 tiles... curr tile: 20170926bC0652700w180730n_15_02.tif
# Processed 12000 tiles... curr tile: 20170924bC0662230w182830n_19_11.tif
# Processed 13000 tiles... curr tile: 20170924bC0655830w182700n_14_16.tif
# Processed 14000 tiles... curr tile: 20170926aC0661630w175830n_11_09.tif
# Processed 15000 tiles... curr tile: 20170926aC0663600w180000n_07_12.tif
# Processed 16000 tiles... curr tile: 20170926aC0664500w180000n_08_04.tif
# Processed 17000 tiles... curr tile: 20170926aC0661630w175700n_01_02.tif
# Processed 18000 tiles... curr tile: 20170925aC0653900w181330n_03_02.tif
# Processed 19000 tiles... curr tile: 20170925aC0653730w182100n_06_02.tif
# Processed 20000 tiles... curr tile: 20170926bC0654800w180730n_10_03.tif
# Processed 21000 tiles... curr tile: 20170926aC0663730w180300n_13_19.tif
# Processed 22000 tiles... curr tile: 20170924aC0655100w180300n_19_12.tif
# Processed 23000 tiles... curr tile: 20170926aC0655230w180900n_06_11.tif
# Processed 24000 tiles... curr tile: 20170926bC0654330w181200n_05_09.tif
# Processed 25000 tiles... curr tile: 20170924bC0655100w182530n_05_11.tif
# Processed 26000 tiles... curr tile: 20170925aC0654500w181330n_04_03.tif
# Processed 27000 tiles... curr tile: 20170924bC0660900w182830n_08_14.tif
# Processed 28000 tiles... curr tile: 20170926bC0652830w180730n_02_18.tif
# Processed 29000 tiles... curr tile: 20170924bC0653730w182230n_02_10.tif
# Processed 30000 tiles... curr tile: 20170924bC0662700w183000n_13_04.tif
# Processed 31000 tiles... curr tile: 20170924bC0660730w182830n_09_08.tif
# Processed 32000 tiles... curr tile: 20170926aC0663430w180130n_19_02.tif
# Processed 33000 tiles... curr tile: 20170926aC0662700w180000n_07_10.tif
# Processed 34000 tiles... curr tile: 20170926bC0655100w181030n_05_15.tif
# Processed 35000 tiles... curr tile: 20170924bC0661200w182830n_16_15.tif
# Processed 36000 tiles... curr tile: 20170926aC0661030w175700n_10_08.tif
# Processed 37000 tiles... curr tile: 20170925aC0653900w182100n_05_13.tif
# Processed 38000 tiles... curr tile: 20170924aC0653130w180600n_02_05.tif
# Processed 39000 tiles... curr tile: 20170924bC0653900w181800n_01_17.tif
# Processed 40000 tiles... curr tile: 20170924aC0654330w181200n_03_05.tif
# Processed 41000 tiles... curr tile: 20170924bC0663130w183000n_10_04.tif
# Processed 42000 tiles... curr tile: 20170924bC0660900w182700n_04_17.tif
# Processed 43000 tiles... curr tile: 20170924bC0660730w182830n_05_04.tif
# Processed 44000 tiles... curr tile: 20170926bC0655100w181030n_10_07.tif
# Processed 45000 tiles... curr tile: 20170924bC0661030w183000n_16_18.tif
# Processed 46000 tiles... curr tile: 20170925aC0654200w181800n_11_11.tif
# Processed 47000 tiles... curr tile: 20170926aC0661200w175700n_02_10.tif
# Processed 48000 tiles... curr tile: 20170926aC0663900w180130n_14_16.tif
# Processed 49000 tiles... curr tile: 20170924aC0654630w181030n_07_09.tif
# Processed 50000 tiles... curr tile: 20170924aC0653430w180730n_04_13.tif
# Processed 51000 tiles... curr tile: 20170926bC0653000w180730n_10_03.tif
# Processed 52000 tiles... curr tile: 20170924bC0655100w182700n_13_12.tif
# Processed 53000 tiles... curr tile: 20170926aC0662400w175830n_17_09.tif
# Processed 54000 tiles... curr tile: 20170925aC0653900w181500n_11_08.tif
# Processed 55000 tiles... curr tile: 20170924bC0660730w182700n_18_13.tif
# Processed 56000 tiles... curr tile: 20170924bC0661800w183000n_14_08.tif
# Processed 57000 tiles... curr tile: 20170926bC0653000w180730n_13_09.tif
# Processed 58000 tiles... curr tile: 20170925aC0654330w181630n_12_15.tif
# Processed 59000 tiles... curr tile: 20170926aC0660900w175700n_03_09.tif
# Processed 60000 tiles... curr tile: 20170926aC0663900w180300n_01_04.tif
# Processed 61000 tiles... curr tile: 20170924bC0660900w183000n_17_13.tif
# Processed 62000 tiles... curr tile: 20170924bC0654030w181500n_01_18.tif
# Processed 63000 tiles... curr tile: 20170924bC0661630w183000n_17_17.tif
# Processed 64000 tiles... curr tile: 20170925aC0654030w181930n_06_19.tif
# Processed 65000 tiles... curr tile: 20170924bC0662830w182700n_13_15.tif
# Processed 66000 tiles... curr tile: 20170926aC0665530w180000n_05_02.tif
# Processed 67000 tiles... curr tile: 20170924bC0654930w182700n_17_07.tif
# Processed 68000 tiles... curr tile: 20170924bC0660730w182830n_13_04.tif
# Processed 69000 tiles... curr tile: 20170924aC0652100w182100n_05_05.tif
# Processed 70000 tiles... curr tile: 20170926aC0663600w175830n_05_09.tif
# Processed 71000 tiles... curr tile: 20170924aC0655100w180300n_16_10.tif
# Processed 72000 tiles... curr tile: 20170924aC0651800w182100n_08_01.tif
# Mapped 72220 tiles to bboxes

# %%
# Map buildings to the tiles they're in to crop them out

# Drop index from the previous join (we don't need it anymore)
all_buildings = all_buildings.drop(['index_left'], axis=1)
buildings_tile_map = gpd.sjoin(all_buildings, tile_coords_map, how="left", op="within")

# Remove buildings for which we don't have any satellite images
buildings_tile_map = buildings_tile_map[pd.notnull(buildings_tile_map['tile_filename'])]
print(len(buildings_tile_map))
print(buildings_tile_map.head())
# Out:
# 240256
#    DMG_LEVEL DMG_TYPE ASMT_TYPE IN_DEPTH WIND_SPEED   PGA ACCESS COUNTY STATE  \
# 2        AFF       WI        RS     None        UNK  None    UNK
# 38       AFF       FL       MOD     None        UNK  None    UNK
# 56       AFF       WI        RS     None        UNK  None    UNK
# 57       AFF       WI        RS     None        UNK  None    UNK
# 59       AFF       WI        RS     None        UNK  None    UNK
#
#     FIPS  ... SOURCE DIS_NUMBER COMMENTS  LONGITUDE   LATITUDE  USNG  \
# 2   None  ...   FEMA       None     None -66.125748  18.440516  None
# 38   NaN  ...   FEMA       None     None -66.075722  18.456402  None
# 56  None  ...   FEMA       None     None -65.810402  18.143759  None
# 57  None  ...   FEMA       None     None -65.829788  18.139668  None
# 59  None  ...   FEMA       None     None -65.825577  18.136524  None
#
#                                              geometry  is_damaged  \
# 2   POLYGON ((-66.1261362 18.4406596, -66.1257715 ...        True
# 38  POLYGON ((-66.075492 18.4563878, -66.075534899...        True
# 56  POLYGON ((-65.80995780000001 18.1442867, -65.8...        True
# 57  POLYGON ((-65.8299779 18.1394224, -65.8300716 ...        True
# 59  POLYGON ((-65.82588440000001 18.1362877, -65.8...        True
#
#     index_right                                      tile_filename
# 2       60726.0  /Users/apando/school/cs230/project/datasets/hu...
# 38      58153.0  /Users/apando/school/cs230/project/datasets/hu...
# 56      23900.0  /Users/apando/school/cs230/project/datasets/hu...
# 57      54087.0  /Users/apando/school/cs230/project/datasets/hu...
# 59      28853.0  /Users/apando/school/cs230/project/datasets/hu...
#
# [5 rows x 24 columns]

# %%
buildings_tile_map.iloc[44]['geometry']

# %%
# Note that it's possible for there to be more rows here than # of buildings,
# because we likely have more than 1 tile for the same buildings.
# To avoid biasing by having the same building in train/test/dev sets,
# the filename with building centroid coords will indicate whether it's the 
# same building or not and we can filter accordingly.
print("Total buildings: {}".format(len(buildings_tile_map)))
print("Damaged buildings: {}".format(len(buildings_tile_map[buildings_tile_map['is_damaged'] == True])))
print("Affected buildings: {}".format(len(buildings_tile_map[buildings_tile_map['DMG_LEVEL'] == 'AFF'])))
print("Destroyed buildings: {}".format(len(buildings_tile_map[buildings_tile_map['DMG_LEVEL'] == 'DES'])))
print("Major damage buildings: {}".format(len(buildings_tile_map[buildings_tile_map['DMG_LEVEL'] == 'MAJ'])))
print("Non-Damaged buildings: {}".format(len(buildings_tile_map[buildings_tile_map['is_damaged'] == False])))
# Out:
# Total buildings: 240256
# Damaged buildings: 38394
# Affected buildings: 20527
# Destroyed buildings: 3658
# Major damage buildings: 5615
# Non-Damaged buildings: 201862

# %%
len(buildings_tile_map[buildings_tile_map['DMG_LEVEL'] == 'AFF'].drop_duplicates(['LATITUDE', 'LONGITUDE']))
# Out:
# 19977

# %%
# Explore different zoom levels
# First zoom level (pre-tuning): 0.00016
# 2nd zoom level: 0.00003
# 3rd zoom level: 0.00024

import random
from rasterio.mask import mask
from rasterio import plot
from shapely.geometry import Point

i = int(random.random()*len(buildings_tile_map))
print(i)
#i = 17492
row = buildings_tile_map.iloc[i]

with rasterio.open(row['tile_filename']) as src:
    building = row['geometry']
    building_center = Point(building.centroid.x, building.centroid.y)
    p = building_center.buffer(0.00024, cap_style=3).envelope
    out_img, out_transform = mask(src, [p], crop=True)
    plot.show(out_img)
    
    out_meta = src.meta.copy()
    
    # Save the resulting raster, as a 128x128 image
    out_meta.update({
        "driver": "JPEG",
        "height": 128,
        "width": 128,
        "transform": out_transform
    })
    
    with rasterio.open('/Users/apando/Downloads/test.jpeg', 'w', **out_meta) as dest:
        dest.write(out_img)
    
print(row['tile_filename'])
# Out:
# 280777
# /Users/apando/school/cs230/project/datasets/hurricane_maria/post_event/noaa/tiles/20170924bC0662400w182830n_02_04.tif

# %%
# Crop out building from the tile, and save it in a separate file
# as a 128x128 px image.

# Hyperparameters here are:
#     - image size
#     - buffer around the building

import numpy as np
from rasterio.mask import mask

BASE_DIR = '/Users/apando/school/cs230/project/datasets/hurricane_maria/building_crops_noaa_rezoom/'

bldg_counter = 0
des_bldg_counter = 0
aff_bldg_counter = 0
maj_bldg_counter = 0
min_bldg_counter = 0
unk_bldg_counter = 0
no_dmg_bldg_counter = 0

for _, row in buildings_tile_map.iterrows():
    bldg_counter += 1
    
    if bldg_counter % 200 == 0:
        print("Processed {0} buildings... {1} DES, {2} AFF, {3} ND".format(bldg_counter, des_bldg_counter, aff_bldg_counter, no_dmg_bldg_counter))
    
    building = row['geometry']
    x, y = building.centroid.x, building.centroid.y
    building_center = Point(x, y)
    with rasterio.open(row['tile_filename']) as src:
        # Add a small square buffer to the building polygon's centroid before cropping.
        p = building_center.buffer(0.00024, cap_style=3).envelope
        out_img, out_transform = mask(src, [p], crop=True)
    out_meta = src.meta.copy()
    
    # Save the resulting raster, as a 128x128 image
    out_meta.update({
        "driver": "JPEG",
        "height": 128,
        "width": 128,
        "transform": out_transform
    })
    
    # Set up data in Keras ImageDataGenerator-friendly format
    dmg_label = 'nd'
    if row['is_damaged']:
        if row['DMG_LEVEL'] == 'DES':
            des_bldg_counter += 1
            dmg_label = 'des'
        elif row['DMG_LEVEL'] == 'AFF':
            aff_bldg_counter += 1
            dmg_label = 'aff'
        elif row['DMG_LEVEL'] == 'MAJ':
            maj_bldg_counter += 1
            dmg_label = 'maj'
        elif row['DMG_LEVEL'] == 'MIN':
            min_bldg_counter += 1
            dmg_label = 'min'
        else:
            unk_bldg_counter += 1
            dmg_label = 'unk'
        out_dir = BASE_DIR + 'damaged/'
    else:
        no_dmg_bldg_counter += 1
        out_dir = BASE_DIR + 'non_damaged/'        
    
    # Preserve tile name in case there's multiple images for 1 building (don't overwrite)
    tile_name = row['tile_filename'].split('/')[-1].split('.')[0]
        
    with rasterio.open(out_dir + '{0},{1}_{2}_{3}.jpeg'.format(x, y, tile_name, dmg_label), 'w', **out_meta) as dest:
        dest.write(out_img)
    
print("Processed {} buildings".format(bldg_counter))
# Out:
# Processed 200 buildings... 18 DES, 135 AFF, 0 ND
# Processed 400 buildings... 19 DES, 302 AFF, 0 ND
# Processed 600 buildings... 20 DES, 398 AFF, 0 ND
# Processed 800 buildings... 26 DES, 533 AFF, 0 ND
# Processed 1000 buildings... 34 DES, 676 AFF, 0 ND
# Processed 1200 buildings... 34 DES, 760 AFF, 0 ND
# Processed 1400 buildings... 34 DES, 849 AFF, 0 ND
# Processed 1600 buildings... 34 DES, 923 AFF, 0 ND
# Processed 1800 buildings... 34 DES, 992 AFF, 0 ND
# Processed 2000 buildings... 34 DES, 1076 AFF, 0 ND
# Processed 2200 buildings... 34 DES, 1154 AFF, 0 ND
# Processed 2400 buildings... 34 DES, 1213 AFF, 0 ND
# Processed 2600 buildings... 34 DES, 1276 AFF, 0 ND
# Processed 2800 buildings... 34 DES, 1365 AFF, 0 ND
# Processed 3000 buildings... 37 DES, 1415 AFF, 0 ND
# Processed 3200 buildings... 41 DES, 1427 AFF, 0 ND
# Processed 3400 buildings... 47 DES, 1434 AFF, 0 ND
# Processed 3600 buildings... 48 DES, 1444 AFF, 0 ND
# Processed 3800 buildings... 51 DES, 1454 AFF, 0 ND
# Processed 4000 buildings... 51 DES, 1549 AFF, 0 ND
# Processed 4200 buildings... 51 DES, 1667 AFF, 0 ND
# Processed 4400 buildings... 52 DES, 1750 AFF, 0 ND
# Processed 4600 buildings... 53 DES, 1822 AFF, 0 ND
# Processed 4800 buildings... 53 DES, 1890 AFF, 0 ND
# Processed 5000 buildings... 53 DES, 1955 AFF, 0 ND
# Processed 5200 buildings... 53 DES, 2019 AFF, 0 ND
# Processed 5400 buildings... 53 DES, 2091 AFF, 0 ND
# Processed 5600 buildings... 55 DES, 2175 AFF, 0 ND
# Processed 5800 buildings... 55 DES, 2260 AFF, 0 ND
# Processed 6000 buildings... 55 DES, 2333 AFF, 0 ND
# Processed 6200 buildings... 55 DES, 2400 AFF, 0 ND
# Processed 6400 buildings... 72 DES, 2430 AFF, 0 ND
# Processed 6600 buildings... 91 DES, 2447 AFF, 0 ND
# Processed 6800 buildings... 110 DES, 2471 AFF, 0 ND
# Processed 7000 buildings... 137 DES, 2489 AFF, 0 ND
# Processed 7200 buildings... 152 DES, 2509 AFF, 0 ND
# Processed 7400 buildings... 164 DES, 2519 AFF, 0 ND
# Processed 7600 buildings... 186 DES, 2534 AFF, 0 ND
# Processed 7800 buildings... 206 DES, 2553 AFF, 0 ND
# Processed 8000 buildings... 226 DES, 2577 AFF, 0 ND
# Processed 8200 buildings... 247 DES, 2600 AFF, 0 ND
# Processed 8400 buildings... 262 DES, 2623 AFF, 0 ND
# Processed 8600 buildings... 279 DES, 2636 AFF, 0 ND
# Processed 8800 buildings... 302 DES, 2659 AFF, 0 ND
# Processed 9000 buildings... 323 DES, 2734 AFF, 0 ND
# Processed 9200 buildings... 332 DES, 2905 AFF, 0 ND
# Processed 9400 buildings... 373 DES, 3023 AFF, 0 ND
# Processed 9600 buildings... 394 DES, 3135 AFF, 0 ND
# Processed 9800 buildings... 407 DES, 3207 AFF, 0 ND
# Processed 10000 buildings... 409 DES, 3213 AFF, 0 ND
# Processed 10200 buildings... 420 DES, 3291 AFF, 0 ND
# Processed 10400 buildings... 456 DES, 3353 AFF, 0 ND
# Processed 10600 buildings... 470 DES, 3488 AFF, 0 ND
# Processed 10800 buildings... 491 DES, 3636 AFF, 0 ND
# Processed 11000 buildings... 501 DES, 3728 AFF, 0 ND
# Processed 11200 buildings... 513 DES, 3840 AFF, 0 ND
# Processed 11400 buildings... 523 DES, 3921 AFF, 0 ND
# Processed 11600 buildings... 537 DES, 4098 AFF, 0 ND
# Processed 11800 buildings... 560 DES, 4269 AFF, 0 ND
# Processed 12000 buildings... 610 DES, 4354 AFF, 0 ND
# Processed 12200 buildings... 620 DES, 4464 AFF, 0 ND
# Processed 12400 buildings... 641 DES, 4599 AFF, 0 ND
# Processed 12600 buildings... 653 DES, 4677 AFF, 0 ND
# Processed 12800 buildings... 658 DES, 4767 AFF, 0 ND
# Processed 13000 buildings... 665 DES, 4945 AFF, 0 ND
# Processed 13200 buildings... 686 DES, 5074 AFF, 0 ND
# Processed 13400 buildings... 696 DES, 5139 AFF, 0 ND
# Processed 13600 buildings... 701 DES, 5223 AFF, 0 ND
# Processed 13800 buildings... 702 DES, 5372 AFF, 0 ND
# Processed 14000 buildings... 705 DES, 5470 AFF, 0 ND
# Processed 14200 buildings... 705 DES, 5652 AFF, 0 ND
# Processed 14400 buildings... 705 DES, 5808 AFF, 0 ND
# Processed 14600 buildings... 707 DES, 5918 AFF, 0 ND
# Processed 14800 buildings... 712 DES, 5978 AFF, 0 ND
# Processed 15000 buildings... 715 DES, 6092 AFF, 0 ND
# Processed 15200 buildings... 721 DES, 6230 AFF, 0 ND
# Processed 15400 buildings... 724 DES, 6385 AFF, 0 ND
# Processed 15600 buildings... 727 DES, 6481 AFF, 0 ND
# Processed 15800 buildings... 734 DES, 6612 AFF, 0 ND
# Processed 16000 buildings... 746 DES, 6752 AFF, 0 ND
# Processed 16200 buildings... 761 DES, 6875 AFF, 0 ND
# Processed 16400 buildings... 768 DES, 6993 AFF, 0 ND
# Processed 16600 buildings... 769 DES, 7185 AFF, 0 ND
# Processed 16800 buildings... 775 DES, 7286 AFF, 0 ND
# Processed 17000 buildings... 777 DES, 7422 AFF, 0 ND
# Processed 17200 buildings... 781 DES, 7610 AFF, 0 ND
# Processed 17400 buildings... 782 DES, 7741 AFF, 0 ND
# Processed 17600 buildings... 804 DES, 7836 AFF, 0 ND
# Processed 17800 buildings... 804 DES, 7908 AFF, 0 ND
# Processed 18000 buildings... 830 DES, 7928 AFF, 0 ND
# Processed 18200 buildings... 834 DES, 8097 AFF, 0 ND
# Processed 18400 buildings... 852 DES, 8196 AFF, 0 ND
# Processed 18600 buildings... 852 DES, 8296 AFF, 0 ND
# Processed 18800 buildings... 853 DES, 8446 AFF, 0 ND
# Processed 19000 buildings... 870 DES, 8576 AFF, 0 ND
# Processed 19200 buildings... 871 DES, 8689 AFF, 0 ND
# Processed 19400 buildings... 878 DES, 8783 AFF, 0 ND
# Processed 19600 buildings... 889 DES, 8845 AFF, 0 ND
# Processed 19800 buildings... 1016 DES, 8918 AFF, 0 ND
# Processed 20000 buildings... 1019 DES, 9102 AFF, 0 ND
# Processed 20200 buildings... 1031 DES, 9191 AFF, 0 ND
# Processed 20400 buildings... 1088 DES, 9280 AFF, 0 ND
# Processed 20600 buildings... 1127 DES, 9332 AFF, 0 ND
# Processed 20800 buildings... 1151 DES, 9386 AFF, 0 ND
# Processed 21000 buildings... 1153 DES, 9478 AFF, 0 ND
# Processed 21200 buildings... 1188 DES, 9614 AFF, 0 ND
# Processed 21400 buildings... 1228 DES, 9685 AFF, 0 ND
# Processed 21600 buildings... 1246 DES, 9772 AFF, 0 ND
# Processed 21800 buildings... 1250 DES, 9897 AFF, 0 ND
# Processed 22000 buildings... 1323 DES, 9979 AFF, 0 ND
# Processed 22200 buildings... 1418 DES, 10063 AFF, 0 ND
# Processed 22400 buildings... 1522 DES, 10136 AFF, 0 ND
# Processed 22600 buildings... 1545 DES, 10293 AFF, 0 ND
# Processed 22800 buildings... 1591 DES, 10415 AFF, 0 ND
# Processed 23000 buildings... 1652 DES, 10538 AFF, 0 ND
# Processed 23200 buildings... 1691 DES, 10624 AFF, 0 ND
# Processed 23400 buildings... 1707 DES, 10757 AFF, 0 ND
# Processed 23600 buildings... 1737 DES, 10894 AFF, 0 ND
# Processed 23800 buildings... 1753 DES, 10967 AFF, 0 ND
# Processed 24000 buildings... 1800 DES, 11033 AFF, 0 ND
# Processed 24200 buildings... 1828 DES, 11110 AFF, 0 ND
# Processed 24400 buildings... 1844 DES, 11187 AFF, 0 ND
# Processed 24600 buildings... 1858 DES, 11325 AFF, 0 ND
# Processed 24800 buildings... 1873 DES, 11406 AFF, 0 ND
# Processed 25000 buildings... 1897 DES, 11514 AFF, 0 ND
# Processed 25200 buildings... 1911 DES, 11655 AFF, 0 ND
# Processed 25400 buildings... 1978 DES, 11744 AFF, 0 ND
# Processed 25600 buildings... 2018 DES, 11841 AFF, 0 ND
# Processed 25800 buildings... 2096 DES, 11930 AFF, 0 ND
# Processed 26000 buildings... 2121 DES, 12086 AFF, 0 ND
# Processed 26200 buildings... 2169 DES, 12224 AFF, 0 ND
# Processed 26400 buildings... 2179 DES, 12407 AFF, 0 ND
# Processed 26600 buildings... 2215 DES, 12516 AFF, 0 ND
# Processed 26800 buildings... 2220 DES, 12704 AFF, 0 ND
# Processed 27000 buildings... 2237 DES, 12832 AFF, 0 ND
# Processed 27200 buildings... 2243 DES, 13002 AFF, 0 ND
# Processed 27400 buildings... 2266 DES, 13144 AFF, 0 ND
# Processed 27600 buildings... 2365 DES, 13194 AFF, 0 ND
# Processed 27800 buildings... 2382 DES, 13259 AFF, 0 ND
# Processed 28000 buildings... 2412 DES, 13381 AFF, 0 ND
# Processed 28200 buildings... 2454 DES, 13529 AFF, 0 ND
# Processed 28400 buildings... 2600 DES, 13556 AFF, 0 ND
# Processed 28600 buildings... 2676 DES, 13661 AFF, 0 ND
# Processed 28800 buildings... 2758 DES, 13707 AFF, 0 ND
# Processed 29000 buildings... 2803 DES, 13810 AFF, 0 ND
# Processed 29200 buildings... 2803 DES, 13989 AFF, 0 ND
# Processed 29400 buildings... 2809 DES, 14157 AFF, 0 ND
# Processed 29600 buildings... 2813 DES, 14314 AFF, 0 ND
# Processed 29800 buildings... 2822 DES, 14444 AFF, 0 ND
# Processed 30000 buildings... 2854 DES, 14580 AFF, 0 ND
# Processed 30200 buildings... 2856 DES, 14727 AFF, 0 ND
# Processed 30400 buildings... 2857 DES, 14883 AFF, 0 ND
# Processed 30600 buildings... 2865 DES, 15050 AFF, 0 ND
# Processed 30800 buildings... 2866 DES, 15229 AFF, 0 ND
# Processed 31000 buildings... 2876 DES, 15351 AFF, 0 ND
# Processed 31200 buildings... 2888 DES, 15455 AFF, 0 ND
# Processed 31400 buildings... 2892 DES, 15541 AFF, 0 ND
# Processed 31600 buildings... 2913 DES, 15665 AFF, 0 ND
# Processed 31800 buildings... 2928 DES, 15787 AFF, 0 ND
# Processed 32000 buildings... 2962 DES, 15908 AFF, 0 ND
# Processed 32200 buildings... 2964 DES, 16086 AFF, 0 ND
# Processed 32400 buildings... 2965 DES, 16271 AFF, 0 ND
# Processed 32600 buildings... 2976 DES, 16431 AFF, 0 ND
# Processed 32800 buildings... 2978 DES, 16602 AFF, 0 ND
# Processed 33000 buildings... 2978 DES, 16802 AFF, 0 ND
# Processed 33200 buildings... 2986 DES, 16978 AFF, 0 ND
# Processed 33400 buildings... 2988 DES, 17150 AFF, 0 ND
# Processed 33600 buildings... 3008 DES, 17285 AFF, 0 ND
# Processed 33800 buildings... 3008 DES, 17451 AFF, 0 ND
# Processed 34000 buildings... 3042 DES, 17584 AFF, 0 ND
# Processed 34200 buildings... 3067 DES, 17745 AFF, 0 ND
# Processed 34400 buildings... 3078 DES, 17923 AFF, 0 ND
# Processed 34600 buildings... 3154 DES, 18023 AFF, 0 ND
# Processed 34800 buildings... 3169 DES, 18202 AFF, 0 ND
# Processed 35000 buildings... 3178 DES, 18363 AFF, 0 ND
# Processed 35200 buildings... 3185 DES, 18485 AFF, 0 ND
# Processed 35400 buildings... 3217 DES, 18619 AFF, 0 ND
# Processed 35600 buildings... 3294 DES, 18667 AFF, 0 ND
# Processed 35800 buildings... 3294 DES, 18852 AFF, 0 ND
# Processed 36000 buildings... 3304 DES, 19015 AFF, 0 ND
# Processed 36200 buildings... 3346 DES, 19124 AFF, 0 ND
# Processed 36400 buildings... 3477 DES, 19158 AFF, 0 ND
# Processed 36600 buildings... 3480 DES, 19320 AFF, 0 ND
# Processed 36800 buildings... 3483 DES, 19459 AFF, 0 ND
# Processed 37000 buildings... 3484 DES, 19581 AFF, 0 ND
# Processed 37200 buildings... 3487 DES, 19771 AFF, 0 ND
# Processed 37400 buildings... 3491 DES, 19941 AFF, 0 ND
# Processed 37600 buildings... 3507 DES, 20093 AFF, 0 ND
# Processed 37800 buildings... 3535 DES, 20206 AFF, 0 ND
# Processed 38000 buildings... 3590 DES, 20315 AFF, 0 ND
# Processed 38200 buildings... 3653 DES, 20395 AFF, 0 ND
# Processed 38400 buildings... 3658 DES, 20527 AFF, 5 ND
# Processed 38600 buildings... 3658 DES, 20527 AFF, 205 ND
# Processed 38800 buildings... 3658 DES, 20527 AFF, 405 ND
# Processed 39000 buildings... 3658 DES, 20527 AFF, 605 ND
# Processed 39200 buildings... 3658 DES, 20527 AFF, 805 ND
# Processed 39400 buildings... 3658 DES, 20527 AFF, 1005 ND
# Processed 39600 buildings... 3658 DES, 20527 AFF, 1205 ND
# Processed 39800 buildings... 3658 DES, 20527 AFF, 1405 ND
# Processed 40000 buildings... 3658 DES, 20527 AFF, 1605 ND
# Processed 40200 buildings... 3658 DES, 20527 AFF, 1805 ND
# Processed 40400 buildings... 3658 DES, 20527 AFF, 2005 ND
# Processed 40600 buildings... 3658 DES, 20527 AFF, 2205 ND
# Processed 40800 buildings... 3658 DES, 20527 AFF, 2405 ND
# Processed 41000 buildings... 3658 DES, 20527 AFF, 2605 ND
# Processed 41200 buildings... 3658 DES, 20527 AFF, 2805 ND
# Processed 41400 buildings... 3658 DES, 20527 AFF, 3005 ND
# Processed 41600 buildings... 3658 DES, 20527 AFF, 3205 ND
# Processed 41800 buildings... 3658 DES, 20527 AFF, 3405 ND
# Processed 42000 buildings... 3658 DES, 20527 AFF, 3605 ND
# Processed 42200 buildings... 3658 DES, 20527 AFF, 3805 ND
# Processed 42400 buildings... 3658 DES, 20527 AFF, 4005 ND
# Processed 42600 buildings... 3658 DES, 20527 AFF, 4205 ND
# Processed 42800 buildings... 3658 DES, 20527 AFF, 4405 ND
# Processed 43000 buildings... 3658 DES, 20527 AFF, 4605 ND
# Processed 43200 buildings... 3658 DES, 20527 AFF, 4805 ND
# Processed 43400 buildings... 3658 DES, 20527 AFF, 5005 ND
# Processed 43600 buildings... 3658 DES, 20527 AFF, 5205 ND
# Processed 43800 buildings... 3658 DES, 20527 AFF, 5405 ND
# Processed 44000 buildings... 3658 DES, 20527 AFF, 5605 ND
# Processed 44200 buildings... 3658 DES, 20527 AFF, 5805 ND
# Processed 44400 buildings... 3658 DES, 20527 AFF, 6005 ND
# Processed 44600 buildings... 3658 DES, 20527 AFF, 6205 ND
# Processed 44800 buildings... 3658 DES, 20527 AFF, 6405 ND
# Processed 45000 buildings... 3658 DES, 20527 AFF, 6605 ND
# Processed 45200 buildings... 3658 DES, 20527 AFF, 6805 ND
# Processed 45400 buildings... 3658 DES, 20527 AFF, 7005 ND
# Processed 45600 buildings... 3658 DES, 20527 AFF, 7205 ND
# Processed 45800 buildings... 3658 DES, 20527 AFF, 7405 ND
# Processed 46000 buildings... 3658 DES, 20527 AFF, 7605 ND
# Processed 46200 buildings... 3658 DES, 20527 AFF, 7805 ND
# Processed 46400 buildings... 3658 DES, 20527 AFF, 8005 ND
# Processed 46600 buildings... 3658 DES, 20527 AFF, 8205 ND
# Processed 46800 buildings... 3658 DES, 20527 AFF, 8405 ND
# Processed 47000 buildings... 3658 DES, 20527 AFF, 8605 ND
# Processed 47200 buildings... 3658 DES, 20527 AFF, 8805 ND
# Processed 47400 buildings... 3658 DES, 20527 AFF, 9005 ND
# Processed 47600 buildings... 3658 DES, 20527 AFF, 9205 ND
# Processed 47800 buildings... 3658 DES, 20527 AFF, 9405 ND
# Processed 48000 buildings... 3658 DES, 20527 AFF, 9605 ND
# Processed 48200 buildings... 3658 DES, 20527 AFF, 9805 ND
# Processed 48400 buildings... 3658 DES, 20527 AFF, 10005 ND
# Processed 48600 buildings... 3658 DES, 20527 AFF, 10205 ND
# Processed 48800 buildings... 3658 DES, 20527 AFF, 10405 ND
# Processed 49000 buildings... 3658 DES, 20527 AFF, 10605 ND
# Processed 49200 buildings... 3658 DES, 20527 AFF, 10805 ND
# Processed 49400 buildings... 3658 DES, 20527 AFF, 11005 ND
# Processed 49600 buildings... 3658 DES, 20527 AFF, 11205 ND
# Processed 49800 buildings... 3658 DES, 20527 AFF, 11405 ND
# Processed 50000 buildings... 3658 DES, 20527 AFF, 11605 ND
# Processed 50200 buildings... 3658 DES, 20527 AFF, 11805 ND
# Processed 50400 buildings... 3658 DES, 20527 AFF, 12005 ND
# Processed 50600 buildings... 3658 DES, 20527 AFF, 12205 ND
# Processed 50800 buildings... 3658 DES, 20527 AFF, 12405 ND
# Processed 51000 buildings... 3658 DES, 20527 AFF, 12605 ND
# Processed 51200 buildings... 3658 DES, 20527 AFF, 12805 ND
# Processed 51400 buildings... 3658 DES, 20527 AFF, 13005 ND
# Processed 51600 buildings... 3658 DES, 20527 AFF, 13205 ND
# Processed 51800 buildings... 3658 DES, 20527 AFF, 13405 ND
# Processed 52000 buildings... 3658 DES, 20527 AFF, 13605 ND
# Processed 52200 buildings... 3658 DES, 20527 AFF, 13805 ND
# Processed 52400 buildings... 3658 DES, 20527 AFF, 14005 ND
# Processed 52600 buildings... 3658 DES, 20527 AFF, 14205 ND
# Processed 52800 buildings... 3658 DES, 20527 AFF, 14405 ND
# Processed 53000 buildings... 3658 DES, 20527 AFF, 14605 ND
# Processed 53200 buildings... 3658 DES, 20527 AFF, 14805 ND
# Processed 53400 buildings... 3658 DES, 20527 AFF, 15005 ND
# Processed 53600 buildings... 3658 DES, 20527 AFF, 15205 ND
# Processed 53800 buildings... 3658 DES, 20527 AFF, 15405 ND
# Processed 54000 buildings... 3658 DES, 20527 AFF, 15605 ND
# Processed 54200 buildings... 3658 DES, 20527 AFF, 15805 ND
# Processed 54400 buildings... 3658 DES, 20527 AFF, 16005 ND
# Processed 54600 buildings... 3658 DES, 20527 AFF, 16205 ND
# Processed 54800 buildings... 3658 DES, 20527 AFF, 16405 ND
# Processed 55000 buildings... 3658 DES, 20527 AFF, 16605 ND
# Processed 55200 buildings... 3658 DES, 20527 AFF, 16805 ND
# Processed 55400 buildings... 3658 DES, 20527 AFF, 17005 ND
# Processed 55600 buildings... 3658 DES, 20527 AFF, 17205 ND
# Processed 55800 buildings... 3658 DES, 20527 AFF, 17405 ND
# Processed 56000 buildings... 3658 DES, 20527 AFF, 17605 ND
# Processed 56200 buildings... 3658 DES, 20527 AFF, 17805 ND
# Processed 56400 buildings... 3658 DES, 20527 AFF, 18005 ND
# Processed 56600 buildings... 3658 DES, 20527 AFF, 18205 ND
# Processed 56800 buildings... 3658 DES, 20527 AFF, 18405 ND
# Processed 57000 buildings... 3658 DES, 20527 AFF, 18605 ND
# Processed 57200 buildings... 3658 DES, 20527 AFF, 18805 ND
# Processed 57400 buildings... 3658 DES, 20527 AFF, 19005 ND
# Processed 57600 buildings... 3658 DES, 20527 AFF, 19205 ND
# Processed 57800 buildings... 3658 DES, 20527 AFF, 19405 ND
# Processed 58000 buildings... 3658 DES, 20527 AFF, 19605 ND
# Processed 58200 buildings... 3658 DES, 20527 AFF, 19805 ND
# Processed 58400 buildings... 3658 DES, 20527 AFF, 20005 ND
# Processed 58600 buildings... 3658 DES, 20527 AFF, 20205 ND
# Processed 58800 buildings... 3658 DES, 20527 AFF, 20405 ND
# Processed 59000 buildings... 3658 DES, 20527 AFF, 20605 ND
# Processed 59200 buildings... 3658 DES, 20527 AFF, 20805 ND
# Processed 59400 buildings... 3658 DES, 20527 AFF, 21005 ND
# Processed 59600 buildings... 3658 DES, 20527 AFF, 21205 ND
# Processed 59800 buildings... 3658 DES, 20527 AFF, 21405 ND
# Processed 60000 buildings... 3658 DES, 20527 AFF, 21605 ND
# Processed 60200 buildings... 3658 DES, 20527 AFF, 21805 ND
# Processed 60400 buildings... 3658 DES, 20527 AFF, 22005 ND
# Processed 60600 buildings... 3658 DES, 20527 AFF, 22205 ND
# Processed 60800 buildings... 3658 DES, 20527 AFF, 22405 ND
# Processed 61000 buildings... 3658 DES, 20527 AFF, 22605 ND
# Processed 61200 buildings... 3658 DES, 20527 AFF, 22805 ND
# Processed 61400 buildings... 3658 DES, 20527 AFF, 23005 ND
# Processed 61600 buildings... 3658 DES, 20527 AFF, 23205 ND
# Processed 61800 buildings... 3658 DES, 20527 AFF, 23405 ND
# Processed 62000 buildings... 3658 DES, 20527 AFF, 23605 ND
# Processed 62200 buildings... 3658 DES, 20527 AFF, 23805 ND
# Processed 62400 buildings... 3658 DES, 20527 AFF, 24005 ND
# Processed 62600 buildings... 3658 DES, 20527 AFF, 24205 ND
# Processed 62800 buildings... 3658 DES, 20527 AFF, 24405 ND
# Processed 63000 buildings... 3658 DES, 20527 AFF, 24605 ND
# Processed 63200 buildings... 3658 DES, 20527 AFF, 24805 ND
# Processed 63400 buildings... 3658 DES, 20527 AFF, 25005 ND
# Processed 63600 buildings... 3658 DES, 20527 AFF, 25205 ND
# Processed 63800 buildings... 3658 DES, 20527 AFF, 25405 ND
# Processed 64000 buildings... 3658 DES, 20527 AFF, 25605 ND
# Processed 64200 buildings... 3658 DES, 20527 AFF, 25805 ND
# Processed 64400 buildings... 3658 DES, 20527 AFF, 26005 ND
# Processed 64600 buildings... 3658 DES, 20527 AFF, 26205 ND
# Processed 64800 buildings... 3658 DES, 20527 AFF, 26405 ND
# Processed 65000 buildings... 3658 DES, 20527 AFF, 26605 ND
# Processed 65200 buildings... 3658 DES, 20527 AFF, 26805 ND
# Processed 65400 buildings... 3658 DES, 20527 AFF, 27005 ND
# Processed 65600 buildings... 3658 DES, 20527 AFF, 27205 ND
# Processed 65800 buildings... 3658 DES, 20527 AFF, 27405 ND
# Processed 66000 buildings... 3658 DES, 20527 AFF, 27605 ND
# Processed 66200 buildings... 3658 DES, 20527 AFF, 27805 ND
# Processed 66400 buildings... 3658 DES, 20527 AFF, 28005 ND
# Processed 66600 buildings... 3658 DES, 20527 AFF, 28205 ND
# Processed 66800 buildings... 3658 DES, 20527 AFF, 28405 ND
# Processed 67000 buildings... 3658 DES, 20527 AFF, 28605 ND
# Processed 67200 buildings... 3658 DES, 20527 AFF, 28805 ND
# Processed 67400 buildings... 3658 DES, 20527 AFF, 29005 ND
# Processed 67600 buildings... 3658 DES, 20527 AFF, 29205 ND
# Processed 67800 buildings... 3658 DES, 20527 AFF, 29405 ND
# Processed 68000 buildings... 3658 DES, 20527 AFF, 29605 ND
# Processed 68200 buildings... 3658 DES, 20527 AFF, 29805 ND
# Processed 68400 buildings... 3658 DES, 20527 AFF, 30005 ND
# Processed 68600 buildings... 3658 DES, 20527 AFF, 30205 ND
# Processed 68800 buildings... 3658 DES, 20527 AFF, 30405 ND
# Processed 69000 buildings... 3658 DES, 20527 AFF, 30605 ND
# Processed 69200 buildings... 3658 DES, 20527 AFF, 30805 ND
# Processed 69400 buildings... 3658 DES, 20527 AFF, 31005 ND
# Processed 69600 buildings... 3658 DES, 20527 AFF, 31205 ND
# Processed 69800 buildings... 3658 DES, 20527 AFF, 31405 ND
# Processed 70000 buildings... 3658 DES, 20527 AFF, 31605 ND
# Processed 70200 buildings... 3658 DES, 20527 AFF, 31805 ND
# Processed 70400 buildings... 3658 DES, 20527 AFF, 32005 ND
# Processed 70600 buildings... 3658 DES, 20527 AFF, 32205 ND
# Processed 70800 buildings... 3658 DES, 20527 AFF, 32405 ND
# Processed 71000 buildings... 3658 DES, 20527 AFF, 32605 ND
# Processed 71200 buildings... 3658 DES, 20527 AFF, 32805 ND
# Processed 71400 buildings... 3658 DES, 20527 AFF, 33005 ND
# Processed 71600 buildings... 3658 DES, 20527 AFF, 33205 ND
# Processed 71800 buildings... 3658 DES, 20527 AFF, 33405 ND
# Processed 72000 buildings... 3658 DES, 20527 AFF, 33605 ND
# Processed 72200 buildings... 3658 DES, 20527 AFF, 33805 ND
# Processed 72400 buildings... 3658 DES, 20527 AFF, 34005 ND
# Processed 72600 buildings... 3658 DES, 20527 AFF, 34205 ND
# Processed 72800 buildings... 3658 DES, 20527 AFF, 34405 ND
# Processed 73000 buildings... 3658 DES, 20527 AFF, 34605 ND
# Processed 73200 buildings... 3658 DES, 20527 AFF, 34805 ND
# Processed 73400 buildings... 3658 DES, 20527 AFF, 35005 ND
# Processed 73600 buildings... 3658 DES, 20527 AFF, 35205 ND
# Processed 73800 buildings... 3658 DES, 20527 AFF, 35405 ND
# Processed 74000 buildings... 3658 DES, 20527 AFF, 35605 ND
# Processed 74200 buildings... 3658 DES, 20527 AFF, 35805 ND
# Processed 74400 buildings... 3658 DES, 20527 AFF, 36005 ND
# Processed 74600 buildings... 3658 DES, 20527 AFF, 36205 ND
# Processed 74800 buildings... 3658 DES, 20527 AFF, 36405 ND
# Processed 75000 buildings... 3658 DES, 20527 AFF, 36605 ND
# Processed 75200 buildings... 3658 DES, 20527 AFF, 36805 ND
# Processed 75400 buildings... 3658 DES, 20527 AFF, 37005 ND
# Processed 75600 buildings... 3658 DES, 20527 AFF, 37205 ND
# Processed 75800 buildings... 3658 DES, 20527 AFF, 37405 ND
# Processed 76000 buildings... 3658 DES, 20527 AFF, 37605 ND
# Processed 76200 buildings... 3658 DES, 20527 AFF, 37805 ND
# Processed 76400 buildings... 3658 DES, 20527 AFF, 38005 ND
# Processed 76600 buildings... 3658 DES, 20527 AFF, 38205 ND
# Processed 76800 buildings... 3658 DES, 20527 AFF, 38405 ND
# Processed 77000 buildings... 3658 DES, 20527 AFF, 38605 ND
# Processed 77200 buildings... 3658 DES, 20527 AFF, 38805 ND
# Processed 77400 buildings... 3658 DES, 20527 AFF, 39005 ND
# Processed 77600 buildings... 3658 DES, 20527 AFF, 39205 ND
# Processed 77800 buildings... 3658 DES, 20527 AFF, 39405 ND
# Processed 78000 buildings... 3658 DES, 20527 AFF, 39605 ND
# Processed 78200 buildings... 3658 DES, 20527 AFF, 39805 ND
# Processed 78400 buildings... 3658 DES, 20527 AFF, 40005 ND
# Processed 78600 buildings... 3658 DES, 20527 AFF, 40205 ND
# Processed 78800 buildings... 3658 DES, 20527 AFF, 40405 ND
# Processed 79000 buildings... 3658 DES, 20527 AFF, 40605 ND
# Processed 79200 buildings... 3658 DES, 20527 AFF, 40805 ND
# Processed 79400 buildings... 3658 DES, 20527 AFF, 41005 ND
# Processed 79600 buildings... 3658 DES, 20527 AFF, 41205 ND
# Processed 79800 buildings... 3658 DES, 20527 AFF, 41405 ND
# Processed 80000 buildings... 3658 DES, 20527 AFF, 41605 ND
# Processed 80200 buildings... 3658 DES, 20527 AFF, 41805 ND
# Processed 80400 buildings... 3658 DES, 20527 AFF, 42005 ND
# Processed 80600 buildings... 3658 DES, 20527 AFF, 42205 ND
# Processed 80800 buildings... 3658 DES, 20527 AFF, 42405 ND
# Processed 81000 buildings... 3658 DES, 20527 AFF, 42605 ND
# Processed 81200 buildings... 3658 DES, 20527 AFF, 42805 ND
# Processed 81400 buildings... 3658 DES, 20527 AFF, 43005 ND
# Processed 81600 buildings... 3658 DES, 20527 AFF, 43205 ND
# Processed 81800 buildings... 3658 DES, 20527 AFF, 43405 ND
# Processed 82000 buildings... 3658 DES, 20527 AFF, 43605 ND
# Processed 82200 buildings... 3658 DES, 20527 AFF, 43805 ND
# Processed 82400 buildings... 3658 DES, 20527 AFF, 44005 ND
# Processed 82600 buildings... 3658 DES, 20527 AFF, 44205 ND
# Processed 82800 buildings... 3658 DES, 20527 AFF, 44405 ND
# Processed 83000 buildings... 3658 DES, 20527 AFF, 44605 ND
# Processed 83200 buildings... 3658 DES, 20527 AFF, 44805 ND
# Processed 83400 buildings... 3658 DES, 20527 AFF, 45005 ND
# Processed 83600 buildings... 3658 DES, 20527 AFF, 45205 ND
# Processed 83800 buildings... 3658 DES, 20527 AFF, 45405 ND
# Processed 84000 buildings... 3658 DES, 20527 AFF, 45605 ND
# Processed 84200 buildings... 3658 DES, 20527 AFF, 45805 ND
# Processed 84400 buildings... 3658 DES, 20527 AFF, 46005 ND
# Processed 84600 buildings... 3658 DES, 20527 AFF, 46205 ND
# Processed 84800 buildings... 3658 DES, 20527 AFF, 46405 ND
# Processed 85000 buildings... 3658 DES, 20527 AFF, 46605 ND
# Processed 85200 buildings... 3658 DES, 20527 AFF, 46805 ND
# Processed 85400 buildings... 3658 DES, 20527 AFF, 47005 ND
# Processed 85600 buildings... 3658 DES, 20527 AFF, 47205 ND
# Processed 85800 buildings... 3658 DES, 20527 AFF, 47405 ND
# Processed 86000 buildings... 3658 DES, 20527 AFF, 47605 ND
# Processed 86200 buildings... 3658 DES, 20527 AFF, 47805 ND
# Processed 86400 buildings... 3658 DES, 20527 AFF, 48005 ND
# Processed 86600 buildings... 3658 DES, 20527 AFF, 48205 ND
# Processed 86800 buildings... 3658 DES, 20527 AFF, 48405 ND
# Processed 87000 buildings... 3658 DES, 20527 AFF, 48605 ND
# Processed 87200 buildings... 3658 DES, 20527 AFF, 48805 ND
# Processed 87400 buildings... 3658 DES, 20527 AFF, 49005 ND
# Processed 87600 buildings... 3658 DES, 20527 AFF, 49205 ND
# Processed 87800 buildings... 3658 DES, 20527 AFF, 49405 ND
# Processed 88000 buildings... 3658 DES, 20527 AFF, 49605 ND
# Processed 88200 buildings... 3658 DES, 20527 AFF, 49805 ND
# Processed 88400 buildings... 3658 DES, 20527 AFF, 50005 ND
# Processed 88600 buildings... 3658 DES, 20527 AFF, 50205 ND
# Processed 88800 buildings... 3658 DES, 20527 AFF, 50405 ND
# Processed 89000 buildings... 3658 DES, 20527 AFF, 50605 ND
# Processed 89200 buildings... 3658 DES, 20527 AFF, 50805 ND
# Processed 89400 buildings... 3658 DES, 20527 AFF, 51005 ND
# Processed 89600 buildings... 3658 DES, 20527 AFF, 51205 ND
# Processed 89800 buildings... 3658 DES, 20527 AFF, 51405 ND
# Processed 90000 buildings... 3658 DES, 20527 AFF, 51605 ND
# Processed 90200 buildings... 3658 DES, 20527 AFF, 51805 ND
# Processed 90400 buildings... 3658 DES, 20527 AFF, 52005 ND
# Processed 90600 buildings... 3658 DES, 20527 AFF, 52205 ND
# Processed 90800 buildings... 3658 DES, 20527 AFF, 52405 ND
# Processed 91000 buildings... 3658 DES, 20527 AFF, 52605 ND
# Processed 91200 buildings... 3658 DES, 20527 AFF, 52805 ND
# Processed 91400 buildings... 3658 DES, 20527 AFF, 53005 ND
# Processed 91600 buildings... 3658 DES, 20527 AFF, 53205 ND
# Processed 91800 buildings... 3658 DES, 20527 AFF, 53405 ND
# Processed 92000 buildings... 3658 DES, 20527 AFF, 53605 ND
# Processed 92200 buildings... 3658 DES, 20527 AFF, 53805 ND
# Processed 92400 buildings... 3658 DES, 20527 AFF, 54005 ND
# Processed 92600 buildings... 3658 DES, 20527 AFF, 54205 ND
# Processed 92800 buildings... 3658 DES, 20527 AFF, 54405 ND
# Processed 93000 buildings... 3658 DES, 20527 AFF, 54605 ND
# Processed 93200 buildings... 3658 DES, 20527 AFF, 54805 ND
# Processed 93400 buildings... 3658 DES, 20527 AFF, 55005 ND
# Processed 93600 buildings... 3658 DES, 20527 AFF, 55205 ND
# Processed 93800 buildings... 3658 DES, 20527 AFF, 55405 ND
# Processed 94000 buildings... 3658 DES, 20527 AFF, 55605 ND
# Processed 94200 buildings... 3658 DES, 20527 AFF, 55805 ND
# Processed 94400 buildings... 3658 DES, 20527 AFF, 56005 ND
# Processed 94600 buildings... 3658 DES, 20527 AFF, 56205 ND
# Processed 94800 buildings... 3658 DES, 20527 AFF, 56405 ND
# Processed 95000 buildings... 3658 DES, 20527 AFF, 56605 ND
# Processed 95200 buildings... 3658 DES, 20527 AFF, 56805 ND
# Processed 95400 buildings... 3658 DES, 20527 AFF, 57005 ND
# Processed 95600 buildings... 3658 DES, 20527 AFF, 57205 ND
# Processed 95800 buildings... 3658 DES, 20527 AFF, 57405 ND
# Processed 96000 buildings... 3658 DES, 20527 AFF, 57605 ND
# Processed 96200 buildings... 3658 DES, 20527 AFF, 57805 ND
# Processed 96400 buildings... 3658 DES, 20527 AFF, 58005 ND
# Processed 96600 buildings... 3658 DES, 20527 AFF, 58205 ND
# Processed 96800 buildings... 3658 DES, 20527 AFF, 58405 ND
# Processed 97000 buildings... 3658 DES, 20527 AFF, 58605 ND
# Processed 97200 buildings... 3658 DES, 20527 AFF, 58805 ND
# Processed 97400 buildings... 3658 DES, 20527 AFF, 59005 ND
# Processed 97600 buildings... 3658 DES, 20527 AFF, 59205 ND
# Processed 97800 buildings... 3658 DES, 20527 AFF, 59405 ND
# Processed 98000 buildings... 3658 DES, 20527 AFF, 59605 ND
# Processed 98200 buildings... 3658 DES, 20527 AFF, 59805 ND
# Processed 98400 buildings... 3658 DES, 20527 AFF, 60005 ND
# Processed 98600 buildings... 3658 DES, 20527 AFF, 60205 ND
# Processed 98800 buildings... 3658 DES, 20527 AFF, 60405 ND
# Processed 99000 buildings... 3658 DES, 20527 AFF, 60605 ND
# Processed 99200 buildings... 3658 DES, 20527 AFF, 60805 ND
# Processed 99400 buildings... 3658 DES, 20527 AFF, 61005 ND
# Processed 99600 buildings... 3658 DES, 20527 AFF, 61205 ND
# Processed 99800 buildings... 3658 DES, 20527 AFF, 61405 ND
# Processed 100000 buildings... 3658 DES, 20527 AFF, 61605 ND
# Processed 100200 buildings... 3658 DES, 20527 AFF, 61805 ND
# Processed 100400 buildings... 3658 DES, 20527 AFF, 62005 ND
# Processed 100600 buildings... 3658 DES, 20527 AFF, 62205 ND
# Processed 100800 buildings... 3658 DES, 20527 AFF, 62405 ND
# Processed 101000 buildings... 3658 DES, 20527 AFF, 62605 ND
# Processed 101200 buildings... 3658 DES, 20527 AFF, 62805 ND
# Processed 101400 buildings... 3658 DES, 20527 AFF, 63005 ND
# Processed 101600 buildings... 3658 DES, 20527 AFF, 63205 ND
# Processed 101800 buildings... 3658 DES, 20527 AFF, 63405 ND
# Processed 102000 buildings... 3658 DES, 20527 AFF, 63605 ND
# Processed 102200 buildings... 3658 DES, 20527 AFF, 63805 ND
# Processed 102400 buildings... 3658 DES, 20527 AFF, 64005 ND
# Processed 102600 buildings... 3658 DES, 20527 AFF, 64205 ND
# Processed 102800 buildings... 3658 DES, 20527 AFF, 64405 ND
# Processed 103000 buildings... 3658 DES, 20527 AFF, 64605 ND
# Processed 103200 buildings... 3658 DES, 20527 AFF, 64805 ND
# Processed 103400 buildings... 3658 DES, 20527 AFF, 65005 ND
# Processed 103600 buildings... 3658 DES, 20527 AFF, 65205 ND
# Processed 103800 buildings... 3658 DES, 20527 AFF, 65405 ND
# Processed 104000 buildings... 3658 DES, 20527 AFF, 65605 ND
# Processed 104200 buildings... 3658 DES, 20527 AFF, 65805 ND
# Processed 104400 buildings... 3658 DES, 20527 AFF, 66005 ND
# Processed 104600 buildings... 3658 DES, 20527 AFF, 66205 ND
# Processed 104800 buildings... 3658 DES, 20527 AFF, 66405 ND
# Processed 105000 buildings... 3658 DES, 20527 AFF, 66605 ND
# Processed 105200 buildings... 3658 DES, 20527 AFF, 66805 ND
# Processed 105400 buildings... 3658 DES, 20527 AFF, 67005 ND
# Processed 105600 buildings... 3658 DES, 20527 AFF, 67205 ND
# Processed 105800 buildings... 3658 DES, 20527 AFF, 67405 ND
# Processed 106000 buildings... 3658 DES, 20527 AFF, 67605 ND
# Processed 106200 buildings... 3658 DES, 20527 AFF, 67805 ND
# Processed 106400 buildings... 3658 DES, 20527 AFF, 68005 ND
# Processed 106600 buildings... 3658 DES, 20527 AFF, 68205 ND
# Processed 106800 buildings... 3658 DES, 20527 AFF, 68405 ND
# Processed 107000 buildings... 3658 DES, 20527 AFF, 68605 ND
# Processed 107200 buildings... 3658 DES, 20527 AFF, 68805 ND
# Processed 107400 buildings... 3658 DES, 20527 AFF, 69005 ND
# Processed 107600 buildings... 3658 DES, 20527 AFF, 69205 ND
# Processed 107800 buildings... 3658 DES, 20527 AFF, 69405 ND
# Processed 108000 buildings... 3658 DES, 20527 AFF, 69605 ND
# Processed 108200 buildings... 3658 DES, 20527 AFF, 69805 ND
# Processed 108400 buildings... 3658 DES, 20527 AFF, 70005 ND
# Processed 108600 buildings... 3658 DES, 20527 AFF, 70205 ND
# Processed 108800 buildings... 3658 DES, 20527 AFF, 70405 ND
# Processed 109000 buildings... 3658 DES, 20527 AFF, 70605 ND
# Processed 109200 buildings... 3658 DES, 20527 AFF, 70805 ND
# Processed 109400 buildings... 3658 DES, 20527 AFF, 71005 ND
# Processed 109600 buildings... 3658 DES, 20527 AFF, 71205 ND
# Processed 109800 buildings... 3658 DES, 20527 AFF, 71405 ND
# Processed 110000 buildings... 3658 DES, 20527 AFF, 71605 ND
# Processed 110200 buildings... 3658 DES, 20527 AFF, 71805 ND
# Processed 110400 buildings... 3658 DES, 20527 AFF, 72005 ND
# Processed 110600 buildings... 3658 DES, 20527 AFF, 72205 ND
# Processed 110800 buildings... 3658 DES, 20527 AFF, 72405 ND
# Processed 111000 buildings... 3658 DES, 20527 AFF, 72605 ND
# Processed 111200 buildings... 3658 DES, 20527 AFF, 72805 ND
# Processed 111400 buildings... 3658 DES, 20527 AFF, 73005 ND
# Processed 111600 buildings... 3658 DES, 20527 AFF, 73205 ND
# Processed 111800 buildings... 3658 DES, 20527 AFF, 73405 ND
# Processed 112000 buildings... 3658 DES, 20527 AFF, 73605 ND
# Processed 112200 buildings... 3658 DES, 20527 AFF, 73805 ND
# Processed 112400 buildings... 3658 DES, 20527 AFF, 74005 ND
# Processed 112600 buildings... 3658 DES, 20527 AFF, 74205 ND
# Processed 112800 buildings... 3658 DES, 20527 AFF, 74405 ND
# Processed 113000 buildings... 3658 DES, 20527 AFF, 74605 ND
# Processed 113200 buildings... 3658 DES, 20527 AFF, 74805 ND
# Processed 113400 buildings... 3658 DES, 20527 AFF, 75005 ND
# Processed 113600 buildings... 3658 DES, 20527 AFF, 75205 ND
# Processed 113800 buildings... 3658 DES, 20527 AFF, 75405 ND
# Processed 114000 buildings... 3658 DES, 20527 AFF, 75605 ND
# Processed 114200 buildings... 3658 DES, 20527 AFF, 75805 ND
# Processed 114400 buildings... 3658 DES, 20527 AFF, 76005 ND
# Processed 114600 buildings... 3658 DES, 20527 AFF, 76205 ND
# Processed 114800 buildings... 3658 DES, 20527 AFF, 76405 ND
# Processed 115000 buildings... 3658 DES, 20527 AFF, 76605 ND
# Processed 115200 buildings... 3658 DES, 20527 AFF, 76805 ND
# Processed 115400 buildings... 3658 DES, 20527 AFF, 77005 ND
# Processed 115600 buildings... 3658 DES, 20527 AFF, 77205 ND
# Processed 115800 buildings... 3658 DES, 20527 AFF, 77405 ND
# Processed 116000 buildings... 3658 DES, 20527 AFF, 77605 ND
# Processed 116200 buildings... 3658 DES, 20527 AFF, 77805 ND
# Processed 116400 buildings... 3658 DES, 20527 AFF, 78005 ND
# Processed 116600 buildings... 3658 DES, 20527 AFF, 78205 ND
# Processed 116800 buildings... 3658 DES, 20527 AFF, 78405 ND
# Processed 117000 buildings... 3658 DES, 20527 AFF, 78605 ND
# Processed 117200 buildings... 3658 DES, 20527 AFF, 78805 ND
# Processed 117400 buildings... 3658 DES, 20527 AFF, 79005 ND
# Processed 117600 buildings... 3658 DES, 20527 AFF, 79205 ND
# Processed 117800 buildings... 3658 DES, 20527 AFF, 79405 ND
# Processed 118000 buildings... 3658 DES, 20527 AFF, 79605 ND
# Processed 118200 buildings... 3658 DES, 20527 AFF, 79805 ND
# Processed 118400 buildings... 3658 DES, 20527 AFF, 80005 ND
# Processed 118600 buildings... 3658 DES, 20527 AFF, 80205 ND
# Processed 118800 buildings... 3658 DES, 20527 AFF, 80405 ND
# Processed 119000 buildings... 3658 DES, 20527 AFF, 80605 ND
# Processed 119200 buildings... 3658 DES, 20527 AFF, 80805 ND
# Processed 119400 buildings... 3658 DES, 20527 AFF, 81005 ND
# Processed 119600 buildings... 3658 DES, 20527 AFF, 81205 ND
# Processed 119800 buildings... 3658 DES, 20527 AFF, 81405 ND
# Processed 120000 buildings... 3658 DES, 20527 AFF, 81605 ND
# Processed 120200 buildings... 3658 DES, 20527 AFF, 81805 ND
# Processed 120400 buildings... 3658 DES, 20527 AFF, 82005 ND
# Processed 120600 buildings... 3658 DES, 20527 AFF, 82205 ND
# Processed 120800 buildings... 3658 DES, 20527 AFF, 82405 ND
# Processed 121000 buildings... 3658 DES, 20527 AFF, 82605 ND
# Processed 121200 buildings... 3658 DES, 20527 AFF, 82805 ND
# Processed 121400 buildings... 3658 DES, 20527 AFF, 83005 ND
# Processed 121600 buildings... 3658 DES, 20527 AFF, 83205 ND
# Processed 121800 buildings... 3658 DES, 20527 AFF, 83405 ND
# Processed 122000 buildings... 3658 DES, 20527 AFF, 83605 ND
# Processed 122200 buildings... 3658 DES, 20527 AFF, 83805 ND
# Processed 122400 buildings... 3658 DES, 20527 AFF, 84005 ND
# Processed 122600 buildings... 3658 DES, 20527 AFF, 84205 ND
# Processed 122800 buildings... 3658 DES, 20527 AFF, 84405 ND
# Processed 123000 buildings... 3658 DES, 20527 AFF, 84605 ND
# Processed 123200 buildings... 3658 DES, 20527 AFF, 84805 ND
# Processed 123400 buildings... 3658 DES, 20527 AFF, 85005 ND
# Processed 123600 buildings... 3658 DES, 20527 AFF, 85205 ND
# Processed 123800 buildings... 3658 DES, 20527 AFF, 85405 ND
# Processed 124000 buildings... 3658 DES, 20527 AFF, 85605 ND
# Processed 124200 buildings... 3658 DES, 20527 AFF, 85805 ND
# Processed 124400 buildings... 3658 DES, 20527 AFF, 86005 ND
# Processed 124600 buildings... 3658 DES, 20527 AFF, 86205 ND
# Processed 124800 buildings... 3658 DES, 20527 AFF, 86405 ND
# Processed 125000 buildings... 3658 DES, 20527 AFF, 86605 ND
# Processed 125200 buildings... 3658 DES, 20527 AFF, 86805 ND
# Processed 125400 buildings... 3658 DES, 20527 AFF, 87005 ND
# Processed 125600 buildings... 3658 DES, 20527 AFF, 87205 ND
# Processed 125800 buildings... 3658 DES, 20527 AFF, 87405 ND
# Processed 126000 buildings... 3658 DES, 20527 AFF, 87605 ND
# Processed 126200 buildings... 3658 DES, 20527 AFF, 87805 ND
# Processed 126400 buildings... 3658 DES, 20527 AFF, 88005 ND
# Processed 126600 buildings... 3658 DES, 20527 AFF, 88205 ND
# Processed 126800 buildings... 3658 DES, 20527 AFF, 88405 ND
# Processed 127000 buildings... 3658 DES, 20527 AFF, 88605 ND
# Processed 127200 buildings... 3658 DES, 20527 AFF, 88805 ND
# Processed 127400 buildings... 3658 DES, 20527 AFF, 89005 ND
# Processed 127600 buildings... 3658 DES, 20527 AFF, 89205 ND
# Processed 127800 buildings... 3658 DES, 20527 AFF, 89405 ND
# Processed 128000 buildings... 3658 DES, 20527 AFF, 89605 ND
# Processed 128200 buildings... 3658 DES, 20527 AFF, 89805 ND
# Processed 128400 buildings... 3658 DES, 20527 AFF, 90005 ND
# Processed 128600 buildings... 3658 DES, 20527 AFF, 90205 ND
# Processed 128800 buildings... 3658 DES, 20527 AFF, 90405 ND
# Processed 129000 buildings... 3658 DES, 20527 AFF, 90605 ND
# Processed 129200 buildings... 3658 DES, 20527 AFF, 90805 ND
# Processed 129400 buildings... 3658 DES, 20527 AFF, 91005 ND
# Processed 129600 buildings... 3658 DES, 20527 AFF, 91205 ND
# Processed 129800 buildings... 3658 DES, 20527 AFF, 91405 ND
# Processed 130000 buildings... 3658 DES, 20527 AFF, 91605 ND
# Processed 130200 buildings... 3658 DES, 20527 AFF, 91805 ND
# Processed 130400 buildings... 3658 DES, 20527 AFF, 92005 ND
# Processed 130600 buildings... 3658 DES, 20527 AFF, 92205 ND
# Processed 130800 buildings... 3658 DES, 20527 AFF, 92405 ND
# Processed 131000 buildings... 3658 DES, 20527 AFF, 92605 ND
# Processed 131200 buildings... 3658 DES, 20527 AFF, 92805 ND
# Processed 131400 buildings... 3658 DES, 20527 AFF, 93005 ND
# Processed 131600 buildings... 3658 DES, 20527 AFF, 93205 ND
# Processed 131800 buildings... 3658 DES, 20527 AFF, 93405 ND
# Processed 132000 buildings... 3658 DES, 20527 AFF, 93605 ND
# Processed 132200 buildings... 3658 DES, 20527 AFF, 93805 ND
# Processed 132400 buildings... 3658 DES, 20527 AFF, 94005 ND
# Processed 132600 buildings... 3658 DES, 20527 AFF, 94205 ND
# Processed 132800 buildings... 3658 DES, 20527 AFF, 94405 ND
# Processed 133000 buildings... 3658 DES, 20527 AFF, 94605 ND
# Processed 133200 buildings... 3658 DES, 20527 AFF, 94805 ND
# Processed 133400 buildings... 3658 DES, 20527 AFF, 95005 ND
# Processed 133600 buildings... 3658 DES, 20527 AFF, 95205 ND
# Processed 133800 buildings... 3658 DES, 20527 AFF, 95405 ND
# Processed 134000 buildings... 3658 DES, 20527 AFF, 95605 ND
# Processed 134200 buildings... 3658 DES, 20527 AFF, 95805 ND
# Processed 134400 buildings... 3658 DES, 20527 AFF, 96005 ND
# Processed 134600 buildings... 3658 DES, 20527 AFF, 96205 ND
# Processed 134800 buildings... 3658 DES, 20527 AFF, 96405 ND
# Processed 135000 buildings... 3658 DES, 20527 AFF, 96605 ND
# Processed 135200 buildings... 3658 DES, 20527 AFF, 96805 ND
# Processed 135400 buildings... 3658 DES, 20527 AFF, 97005 ND
# Processed 135600 buildings... 3658 DES, 20527 AFF, 97205 ND
# Processed 135800 buildings... 3658 DES, 20527 AFF, 97405 ND
# Processed 136000 buildings... 3658 DES, 20527 AFF, 97605 ND
# Processed 136200 buildings... 3658 DES, 20527 AFF, 97805 ND
# Processed 136400 buildings... 3658 DES, 20527 AFF, 98005 ND
# Processed 136600 buildings... 3658 DES, 20527 AFF, 98205 ND
# Processed 136800 buildings... 3658 DES, 20527 AFF, 98405 ND
# Processed 137000 buildings... 3658 DES, 20527 AFF, 98605 ND
# Processed 137200 buildings... 3658 DES, 20527 AFF, 98805 ND
# Processed 137400 buildings... 3658 DES, 20527 AFF, 99005 ND
# Processed 137600 buildings... 3658 DES, 20527 AFF, 99205 ND
# Processed 137800 buildings... 3658 DES, 20527 AFF, 99405 ND
# Processed 138000 buildings... 3658 DES, 20527 AFF, 99605 ND
# Processed 138200 buildings... 3658 DES, 20527 AFF, 99805 ND
# Processed 138400 buildings... 3658 DES, 20527 AFF, 100005 ND
# Processed 138600 buildings... 3658 DES, 20527 AFF, 100205 ND
# Processed 138800 buildings... 3658 DES, 20527 AFF, 100405 ND
# Processed 139000 buildings... 3658 DES, 20527 AFF, 100605 ND
# Processed 139200 buildings... 3658 DES, 20527 AFF, 100805 ND
# Processed 139400 buildings... 3658 DES, 20527 AFF, 101005 ND
# Processed 139600 buildings... 3658 DES, 20527 AFF, 101205 ND
# Processed 139800 buildings... 3658 DES, 20527 AFF, 101405 ND
# Processed 140000 buildings... 3658 DES, 20527 AFF, 101605 ND
# Processed 140200 buildings... 3658 DES, 20527 AFF, 101805 ND
# Processed 140400 buildings... 3658 DES, 20527 AFF, 102005 ND
# Processed 140600 buildings... 3658 DES, 20527 AFF, 102205 ND
# Processed 140800 buildings... 3658 DES, 20527 AFF, 102405 ND
# Processed 141000 buildings... 3658 DES, 20527 AFF, 102605 ND
# Processed 141200 buildings... 3658 DES, 20527 AFF, 102805 ND
# Processed 141400 buildings... 3658 DES, 20527 AFF, 103005 ND
# Processed 141600 buildings... 3658 DES, 20527 AFF, 103205 ND
# Processed 141800 buildings... 3658 DES, 20527 AFF, 103405 ND
# Processed 142000 buildings... 3658 DES, 20527 AFF, 103605 ND
# Processed 142200 buildings... 3658 DES, 20527 AFF, 103805 ND
# Processed 142400 buildings... 3658 DES, 20527 AFF, 104005 ND
# Processed 142600 buildings... 3658 DES, 20527 AFF, 104205 ND
# Processed 142800 buildings... 3658 DES, 20527 AFF, 104405 ND
# Processed 143000 buildings... 3658 DES, 20527 AFF, 104605 ND
# Processed 143200 buildings... 3658 DES, 20527 AFF, 104805 ND
# Processed 143400 buildings... 3658 DES, 20527 AFF, 105005 ND
# Processed 143600 buildings... 3658 DES, 20527 AFF, 105205 ND
# Processed 143800 buildings... 3658 DES, 20527 AFF, 105405 ND
# Processed 144000 buildings... 3658 DES, 20527 AFF, 105605 ND
# Processed 144200 buildings... 3658 DES, 20527 AFF, 105805 ND
# Processed 144400 buildings... 3658 DES, 20527 AFF, 106005 ND
# Processed 144600 buildings... 3658 DES, 20527 AFF, 106205 ND
# Processed 144800 buildings... 3658 DES, 20527 AFF, 106405 ND
# Processed 145000 buildings... 3658 DES, 20527 AFF, 106605 ND
# Processed 145200 buildings... 3658 DES, 20527 AFF, 106805 ND
# Processed 145400 buildings... 3658 DES, 20527 AFF, 107005 ND
# Processed 145600 buildings... 3658 DES, 20527 AFF, 107205 ND
# Processed 145800 buildings... 3658 DES, 20527 AFF, 107405 ND
# Processed 146000 buildings... 3658 DES, 20527 AFF, 107605 ND
# Processed 146200 buildings... 3658 DES, 20527 AFF, 107805 ND
# Processed 146400 buildings... 3658 DES, 20527 AFF, 108005 ND
# Processed 146600 buildings... 3658 DES, 20527 AFF, 108205 ND
# Processed 146800 buildings... 3658 DES, 20527 AFF, 108405 ND
# Processed 147000 buildings... 3658 DES, 20527 AFF, 108605 ND
# Processed 147200 buildings... 3658 DES, 20527 AFF, 108805 ND
# Processed 147400 buildings... 3658 DES, 20527 AFF, 109005 ND
# Processed 147600 buildings... 3658 DES, 20527 AFF, 109205 ND
# Processed 147800 buildings... 3658 DES, 20527 AFF, 109405 ND
# Processed 148000 buildings... 3658 DES, 20527 AFF, 109605 ND
# Processed 148200 buildings... 3658 DES, 20527 AFF, 109805 ND
# Processed 148400 buildings... 3658 DES, 20527 AFF, 110005 ND
# Processed 148600 buildings... 3658 DES, 20527 AFF, 110205 ND
# Processed 148800 buildings... 3658 DES, 20527 AFF, 110405 ND
# Processed 149000 buildings... 3658 DES, 20527 AFF, 110605 ND
# Processed 149200 buildings... 3658 DES, 20527 AFF, 110805 ND
# Processed 149400 buildings... 3658 DES, 20527 AFF, 111005 ND
# Processed 149600 buildings... 3658 DES, 20527 AFF, 111205 ND
# Processed 149800 buildings... 3658 DES, 20527 AFF, 111405 ND
# Processed 150000 buildings... 3658 DES, 20527 AFF, 111605 ND
# Processed 150200 buildings... 3658 DES, 20527 AFF, 111805 ND
# Processed 150400 buildings... 3658 DES, 20527 AFF, 112005 ND
# Processed 150600 buildings... 3658 DES, 20527 AFF, 112205 ND
# Processed 150800 buildings... 3658 DES, 20527 AFF, 112405 ND
# Processed 151000 buildings... 3658 DES, 20527 AFF, 112605 ND
# Processed 151200 buildings... 3658 DES, 20527 AFF, 112805 ND
# Processed 151400 buildings... 3658 DES, 20527 AFF, 113005 ND
# Processed 151600 buildings... 3658 DES, 20527 AFF, 113205 ND
# Processed 151800 buildings... 3658 DES, 20527 AFF, 113405 ND
# Processed 152000 buildings... 3658 DES, 20527 AFF, 113605 ND
# Processed 152200 buildings... 3658 DES, 20527 AFF, 113805 ND
# Processed 152400 buildings... 3658 DES, 20527 AFF, 114005 ND
# Processed 152600 buildings... 3658 DES, 20527 AFF, 114205 ND
# Processed 152800 buildings... 3658 DES, 20527 AFF, 114405 ND
# Processed 153000 buildings... 3658 DES, 20527 AFF, 114605 ND
# Processed 153200 buildings... 3658 DES, 20527 AFF, 114805 ND
# Processed 153400 buildings... 3658 DES, 20527 AFF, 115005 ND
# Processed 153600 buildings... 3658 DES, 20527 AFF, 115205 ND
# Processed 153800 buildings... 3658 DES, 20527 AFF, 115405 ND
# Processed 154000 buildings... 3658 DES, 20527 AFF, 115605 ND
# Processed 154200 buildings... 3658 DES, 20527 AFF, 115805 ND
# Processed 154400 buildings... 3658 DES, 20527 AFF, 116005 ND
# Processed 154600 buildings... 3658 DES, 20527 AFF, 116205 ND
# Processed 154800 buildings... 3658 DES, 20527 AFF, 116405 ND
# Processed 155000 buildings... 3658 DES, 20527 AFF, 116605 ND
# Processed 155200 buildings... 3658 DES, 20527 AFF, 116805 ND
# Processed 155400 buildings... 3658 DES, 20527 AFF, 117005 ND
# Processed 155600 buildings... 3658 DES, 20527 AFF, 117205 ND
# Processed 155800 buildings... 3658 DES, 20527 AFF, 117405 ND
# Processed 156000 buildings... 3658 DES, 20527 AFF, 117605 ND
# Processed 156200 buildings... 3658 DES, 20527 AFF, 117805 ND
# Processed 156400 buildings... 3658 DES, 20527 AFF, 118005 ND
# Processed 156600 buildings... 3658 DES, 20527 AFF, 118205 ND
# Processed 156800 buildings... 3658 DES, 20527 AFF, 118405 ND
# Processed 157000 buildings... 3658 DES, 20527 AFF, 118605 ND
# Processed 157200 buildings... 3658 DES, 20527 AFF, 118805 ND
# Processed 157400 buildings... 3658 DES, 20527 AFF, 119005 ND
# Processed 157600 buildings... 3658 DES, 20527 AFF, 119205 ND
# Processed 157800 buildings... 3658 DES, 20527 AFF, 119405 ND
# Processed 158000 buildings... 3658 DES, 20527 AFF, 119605 ND
# Processed 158200 buildings... 3658 DES, 20527 AFF, 119805 ND
# Processed 158400 buildings... 3658 DES, 20527 AFF, 120005 ND
# Processed 158600 buildings... 3658 DES, 20527 AFF, 120205 ND
# Processed 158800 buildings... 3658 DES, 20527 AFF, 120405 ND
# Processed 159000 buildings... 3658 DES, 20527 AFF, 120605 ND
# Processed 159200 buildings... 3658 DES, 20527 AFF, 120805 ND
# Processed 159400 buildings... 3658 DES, 20527 AFF, 121005 ND
# Processed 159600 buildings... 3658 DES, 20527 AFF, 121205 ND
# Processed 159800 buildings... 3658 DES, 20527 AFF, 121405 ND
# Processed 160000 buildings... 3658 DES, 20527 AFF, 121605 ND
# Processed 160200 buildings... 3658 DES, 20527 AFF, 121805 ND
# Processed 160400 buildings... 3658 DES, 20527 AFF, 122005 ND
# Processed 160600 buildings... 3658 DES, 20527 AFF, 122205 ND
# Processed 160800 buildings... 3658 DES, 20527 AFF, 122405 ND
# Processed 161000 buildings... 3658 DES, 20527 AFF, 122605 ND
# Processed 161200 buildings... 3658 DES, 20527 AFF, 122805 ND
# Processed 161400 buildings... 3658 DES, 20527 AFF, 123005 ND
# Processed 161600 buildings... 3658 DES, 20527 AFF, 123205 ND
# Processed 161800 buildings... 3658 DES, 20527 AFF, 123405 ND
# Processed 162000 buildings... 3658 DES, 20527 AFF, 123605 ND
# Processed 162200 buildings... 3658 DES, 20527 AFF, 123805 ND
# Processed 162400 buildings... 3658 DES, 20527 AFF, 124005 ND
# Processed 162600 buildings... 3658 DES, 20527 AFF, 124205 ND
# Processed 162800 buildings... 3658 DES, 20527 AFF, 124405 ND
# Processed 163000 buildings... 3658 DES, 20527 AFF, 124605 ND
# Processed 163200 buildings... 3658 DES, 20527 AFF, 124805 ND
# Processed 163400 buildings... 3658 DES, 20527 AFF, 125005 ND
# Processed 163600 buildings... 3658 DES, 20527 AFF, 125205 ND
# Processed 163800 buildings... 3658 DES, 20527 AFF, 125405 ND
# Processed 164000 buildings... 3658 DES, 20527 AFF, 125605 ND
# Processed 164200 buildings... 3658 DES, 20527 AFF, 125805 ND
# Processed 164400 buildings... 3658 DES, 20527 AFF, 126005 ND
# Processed 164600 buildings... 3658 DES, 20527 AFF, 126205 ND
# Processed 164800 buildings... 3658 DES, 20527 AFF, 126405 ND
# ...
# Processed 188200 buildings... 3658 DES, 20527 AFF, 149805 ND
# Processed 188400 buildings... 3658 DES, 20527 AFF, 150005 ND
# Processed 188600 buildings... 3658 DES, 20527 AFF, 150205 ND
# Processed 188800 buildings... 3658 DES, 20527 AFF, 150405 ND
# Processed 189000 buildings... 3658 DES, 20527 AFF, 150605 ND
# Processed 189200 buildings... 3658 DES, 20527 AFF, 150805 ND
# Processed 189400 buildings... 3658 DES, 20527 AFF, 151005 ND
# Processed 189600 buildings... 3658 DES, 20527 AFF, 151205 ND
# Processed 189800 buildings... 3658 DES, 20527 AFF, 151405 ND
# Processed 190000 buildings... 3658 DES, 20527 AFF, 151605 ND
# Processed 190200 buildings... 3658 DES, 20527 AFF, 151805 ND
# Processed 190400 buildings... 3658 DES, 20527 AFF, 152005 ND
# Processed 190600 buildings... 3658 DES, 20527 AFF, 152205 ND
# Processed 190800 buildings... 3658 DES, 20527 AFF, 152405 ND
# Processed 191000 buildings... 3658 DES, 20527 AFF, 152605 ND
# Processed 191200 buildings... 3658 DES, 20527 AFF, 152805 ND
# Processed 191400 buildings... 3658 DES, 20527 AFF, 153005 ND
# Processed 191600 buildings... 3658 DES, 20527 AFF, 153205 ND
# Processed 191800 buildings... 3658 DES, 20527 AFF, 153405 ND
# Processed 192000 buildings... 3658 DES, 20527 AFF, 153605 ND
# Processed 192200 buildings... 3658 DES, 20527 AFF, 153805 ND
# Processed 192400 buildings... 3658 DES, 20527 AFF, 154005 ND
# Processed 192600 buildings... 3658 DES, 20527 AFF, 154205 ND
# Processed 192800 buildings... 3658 DES, 20527 AFF, 154405 ND
# Processed 193000 buildings... 3658 DES, 20527 AFF, 154605 ND
# Processed 193200 buildings... 3658 DES, 20527 AFF, 154805 ND
# Processed 193400 buildings... 3658 DES, 20527 AFF, 155005 ND
# Processed 193600 buildings... 3658 DES, 20527 AFF, 155205 ND
# Processed 193800 buildings... 3658 DES, 20527 AFF, 155405 ND
# Processed 194000 buildings... 3658 DES, 20527 AFF, 155605 ND
# Processed 194200 buildings... 3658 DES, 20527 AFF, 155805 ND
# Processed 194400 buildings... 3658 DES, 20527 AFF, 156005 ND
# Processed 194600 buildings... 3658 DES, 20527 AFF, 156205 ND
# Processed 194800 buildings... 3658 DES, 20527 AFF, 156405 ND
# Processed 195000 buildings... 3658 DES, 20527 AFF, 156605 ND
# Processed 195200 buildings... 3658 DES, 20527 AFF, 156805 ND
# Processed 195400 buildings... 3658 DES, 20527 AFF, 157005 ND
# Processed 195600 buildings... 3658 DES, 20527 AFF, 157205 ND
# Processed 195800 buildings... 3658 DES, 20527 AFF, 157405 ND
# Processed 196000 buildings... 3658 DES, 20527 AFF, 157605 ND
# Processed 196200 buildings... 3658 DES, 20527 AFF, 157805 ND
# Processed 196400 buildings... 3658 DES, 20527 AFF, 158005 ND
# Processed 196600 buildings... 3658 DES, 20527 AFF, 158205 ND
# Processed 196800 buildings... 3658 DES, 20527 AFF, 158405 ND
# Processed 197000 buildings... 3658 DES, 20527 AFF, 158605 ND
# Processed 197200 buildings... 3658 DES, 20527 AFF, 158805 ND
# Processed 197400 buildings... 3658 DES, 20527 AFF, 159005 ND
# Processed 197600 buildings... 3658 DES, 20527 AFF, 159205 ND
# Processed 197800 buildings... 3658 DES, 20527 AFF, 159405 ND
# Processed 198000 buildings... 3658 DES, 20527 AFF, 159605 ND
# Processed 198200 buildings... 3658 DES, 20527 AFF, 159805 ND
# Processed 198400 buildings... 3658 DES, 20527 AFF, 160005 ND
# Processed 198600 buildings... 3658 DES, 20527 AFF, 160205 ND
# Processed 198800 buildings... 3658 DES, 20527 AFF, 160405 ND
# Processed 199000 buildings... 3658 DES, 20527 AFF, 160605 ND
# Processed 199200 buildings... 3658 DES, 20527 AFF, 160805 ND
# Processed 199400 buildings... 3658 DES, 20527 AFF, 161005 ND
# Processed 199600 buildings... 3658 DES, 20527 AFF, 161205 ND
# Processed 199800 buildings... 3658 DES, 20527 AFF, 161405 ND
# Processed 200000 buildings... 3658 DES, 20527 AFF, 161605 ND
# Processed 200200 buildings... 3658 DES, 20527 AFF, 161805 ND
# Processed 200400 buildings... 3658 DES, 20527 AFF, 162005 ND
# Processed 200600 buildings... 3658 DES, 20527 AFF, 162205 ND
# Processed 200800 buildings... 3658 DES, 20527 AFF, 162405 ND
# Processed 201000 buildings... 3658 DES, 20527 AFF, 162605 ND
# Processed 201200 buildings... 3658 DES, 20527 AFF, 162805 ND
# Processed 201400 buildings... 3658 DES, 20527 AFF, 163005 ND
# Processed 201600 buildings... 3658 DES, 20527 AFF, 163205 ND
# Processed 201800 buildings... 3658 DES, 20527 AFF, 163405 ND
# Processed 202000 buildings... 3658 DES, 20527 AFF, 163605 ND
# Processed 202200 buildings... 3658 DES, 20527 AFF, 163805 ND
# Processed 202400 buildings... 3658 DES, 20527 AFF, 164005 ND
# Processed 202600 buildings... 3658 DES, 20527 AFF, 164205 ND
# Processed 202800 buildings... 3658 DES, 20527 AFF, 164405 ND
# Processed 203000 buildings... 3658 DES, 20527 AFF, 164605 ND
# Processed 203200 buildings... 3658 DES, 20527 AFF, 164805 ND
# Processed 203400 buildings... 3658 DES, 20527 AFF, 165005 ND
# Processed 203600 buildings... 3658 DES, 20527 AFF, 165205 ND
# Processed 203800 buildings... 3658 DES, 20527 AFF, 165405 ND
# Processed 204000 buildings... 3658 DES, 20527 AFF, 165605 ND
# Processed 204200 buildings... 3658 DES, 20527 AFF, 165805 ND
# Processed 204400 buildings... 3658 DES, 20527 AFF, 166005 ND
# Processed 204600 buildings... 3658 DES, 20527 AFF, 166205 ND
# Processed 204800 buildings... 3658 DES, 20527 AFF, 166405 ND
# Processed 205000 buildings... 3658 DES, 20527 AFF, 166605 ND
# Processed 205200 buildings... 3658 DES, 20527 AFF, 166805 ND
# Processed 205400 buildings... 3658 DES, 20527 AFF, 167005 ND
# Processed 205600 buildings... 3658 DES, 20527 AFF, 167205 ND
# Processed 205800 buildings... 3658 DES, 20527 AFF, 167405 ND
# Processed 206000 buildings... 3658 DES, 20527 AFF, 167605 ND
# Processed 206200 buildings... 3658 DES, 20527 AFF, 167805 ND
# Processed 206400 buildings... 3658 DES, 20527 AFF, 168005 ND
# Processed 206600 buildings... 3658 DES, 20527 AFF, 168205 ND
# Processed 206800 buildings... 3658 DES, 20527 AFF, 168405 ND
# Processed 207000 buildings... 3658 DES, 20527 AFF, 168605 ND
# Processed 207200 buildings... 3658 DES, 20527 AFF, 168805 ND
# Processed 207400 buildings... 3658 DES, 20527 AFF, 169005 ND
# Processed 207600 buildings... 3658 DES, 20527 AFF, 169205 ND
# Processed 207800 buildings... 3658 DES, 20527 AFF, 169405 ND
# Processed 208000 buildings... 3658 DES, 20527 AFF, 169605 ND
# Processed 208200 buildings... 3658 DES, 20527 AFF, 169805 ND
# Processed 208400 buildings... 3658 DES, 20527 AFF, 170005 ND
# Processed 208600 buildings... 3658 DES, 20527 AFF, 170205 ND
# Processed 208800 buildings... 3658 DES, 20527 AFF, 170405 ND
# Processed 209000 buildings... 3658 DES, 20527 AFF, 170605 ND
# Processed 209200 buildings... 3658 DES, 20527 AFF, 170805 ND
# Processed 209400 buildings... 3658 DES, 20527 AFF, 171005 ND
# Processed 209600 buildings... 3658 DES, 20527 AFF, 171205 ND
# Processed 209800 buildings... 3658 DES, 20527 AFF, 171405 ND
# Processed 210000 buildings... 3658 DES, 20527 AFF, 171605 ND
# Processed 210200 buildings... 3658 DES, 20527 AFF, 171805 ND
# Processed 210400 buildings... 3658 DES, 20527 AFF, 172005 ND
# Processed 210600 buildings... 3658 DES, 20527 AFF, 172205 ND
# Processed 210800 buildings... 3658 DES, 20527 AFF, 172405 ND
# Processed 211000 buildings... 3658 DES, 20527 AFF, 172605 ND
# Processed 211200 buildings... 3658 DES, 20527 AFF, 172805 ND
# Processed 211400 buildings... 3658 DES, 20527 AFF, 173005 ND
# Processed 211600 buildings... 3658 DES, 20527 AFF, 173205 ND
# Processed 211800 buildings... 3658 DES, 20527 AFF, 173405 ND
# Processed 212000 buildings... 3658 DES, 20527 AFF, 173605 ND
# Processed 212200 buildings... 3658 DES, 20527 AFF, 173805 ND
# Processed 212400 buildings... 3658 DES, 20527 AFF, 174005 ND
# Processed 212600 buildings... 3658 DES, 20527 AFF, 174205 ND
# Processed 212800 buildings... 3658 DES, 20527 AFF, 174405 ND
# Processed 213000 buildings... 3658 DES, 20527 AFF, 174605 ND
# Processed 213200 buildings... 3658 DES, 20527 AFF, 174805 ND
# Processed 213400 buildings... 3658 DES, 20527 AFF, 175005 ND
# Processed 213600 buildings... 3658 DES, 20527 AFF, 175205 ND
# Processed 213800 buildings... 3658 DES, 20527 AFF, 175405 ND
# Processed 214000 buildings... 3658 DES, 20527 AFF, 175605 ND
# Processed 214200 buildings... 3658 DES, 20527 AFF, 175805 ND
# Processed 214400 buildings... 3658 DES, 20527 AFF, 176005 ND
# Processed 214600 buildings... 3658 DES, 20527 AFF, 176205 ND
# Processed 214800 buildings... 3658 DES, 20527 AFF, 176405 ND
# Processed 215000 buildings... 3658 DES, 20527 AFF, 176605 ND
# Processed 215200 buildings... 3658 DES, 20527 AFF, 176805 ND
# Processed 215400 buildings... 3658 DES, 20527 AFF, 177005 ND
# Processed 215600 buildings... 3658 DES, 20527 AFF, 177205 ND
# Processed 215800 buildings... 3658 DES, 20527 AFF, 177405 ND
# Processed 216000 buildings... 3658 DES, 20527 AFF, 177605 ND
# Processed 216200 buildings... 3658 DES, 20527 AFF, 177805 ND
# Processed 216400 buildings... 3658 DES, 20527 AFF, 178005 ND
# Processed 216600 buildings... 3658 DES, 20527 AFF, 178205 ND
# Processed 216800 buildings... 3658 DES, 20527 AFF, 178405 ND
# Processed 217000 buildings... 3658 DES, 20527 AFF, 178605 ND
# Processed 217200 buildings... 3658 DES, 20527 AFF, 178805 ND
# Processed 217400 buildings... 3658 DES, 20527 AFF, 179005 ND
# Processed 217600 buildings... 3658 DES, 20527 AFF, 179205 ND
# Processed 217800 buildings... 3658 DES, 20527 AFF, 179405 ND
# Processed 218000 buildings... 3658 DES, 20527 AFF, 179605 ND
# Processed 218200 buildings... 3658 DES, 20527 AFF, 179805 ND
# Processed 218400 buildings... 3658 DES, 20527 AFF, 180005 ND
# Processed 218600 buildings... 3658 DES, 20527 AFF, 180205 ND
# Processed 218800 buildings... 3658 DES, 20527 AFF, 180405 ND
# Processed 219000 buildings... 3658 DES, 20527 AFF, 180605 ND
# Processed 219200 buildings... 3658 DES, 20527 AFF, 180805 ND
# Processed 219400 buildings... 3658 DES, 20527 AFF, 181005 ND
# Processed 219600 buildings... 3658 DES, 20527 AFF, 181205 ND
# Processed 219800 buildings... 3658 DES, 20527 AFF, 181405 ND
# Processed 220000 buildings... 3658 DES, 20527 AFF, 181605 ND
# Processed 220200 buildings... 3658 DES, 20527 AFF, 181805 ND
# Processed 220400 buildings... 3658 DES, 20527 AFF, 182005 ND
# Processed 220600 buildings... 3658 DES, 20527 AFF, 182205 ND
# Processed 220800 buildings... 3658 DES, 20527 AFF, 182405 ND
# Processed 221000 buildings... 3658 DES, 20527 AFF, 182605 ND
# Processed 221200 buildings... 3658 DES, 20527 AFF, 182805 ND
# Processed 221400 buildings... 3658 DES, 20527 AFF, 183005 ND
# Processed 221600 buildings... 3658 DES, 20527 AFF, 183205 ND
# Processed 221800 buildings... 3658 DES, 20527 AFF, 183405 ND
# Processed 222000 buildings... 3658 DES, 20527 AFF, 183605 ND
# Processed 222200 buildings... 3658 DES, 20527 AFF, 183805 ND
# Processed 222400 buildings... 3658 DES, 20527 AFF, 184005 ND
# Processed 222600 buildings... 3658 DES, 20527 AFF, 184205 ND
# Processed 222800 buildings... 3658 DES, 20527 AFF, 184405 ND
# Processed 223000 buildings... 3658 DES, 20527 AFF, 184605 ND
# Processed 223200 buildings... 3658 DES, 20527 AFF, 184805 ND
# Processed 223400 buildings... 3658 DES, 20527 AFF, 185005 ND
# Processed 223600 buildings... 3658 DES, 20527 AFF, 185205 ND
# Processed 223800 buildings... 3658 DES, 20527 AFF, 185405 ND
# Processed 224000 buildings... 3658 DES, 20527 AFF, 185605 ND
# Processed 224200 buildings... 3658 DES, 20527 AFF, 185805 ND
# Processed 224400 buildings... 3658 DES, 20527 AFF, 186005 ND
# Processed 224600 buildings... 3658 DES, 20527 AFF, 186205 ND
# Processed 224800 buildings... 3658 DES, 20527 AFF, 186405 ND
# Processed 225000 buildings... 3658 DES, 20527 AFF, 186605 ND
# Processed 225200 buildings... 3658 DES, 20527 AFF, 186805 ND
# Processed 225400 buildings... 3658 DES, 20527 AFF, 187005 ND
# Processed 225600 buildings... 3658 DES, 20527 AFF, 187205 ND
# Processed 225800 buildings... 3658 DES, 20527 AFF, 187405 ND
# Processed 226000 buildings... 3658 DES, 20527 AFF, 187605 ND
# Processed 226200 buildings... 3658 DES, 20527 AFF, 187805 ND
# Processed 226400 buildings... 3658 DES, 20527 AFF, 188005 ND
# Processed 226600 buildings... 3658 DES, 20527 AFF, 188205 ND
# Processed 226800 buildings... 3658 DES, 20527 AFF, 188405 ND
# Processed 227000 buildings... 3658 DES, 20527 AFF, 188605 ND
# Processed 227200 buildings... 3658 DES, 20527 AFF, 188805 ND
# Processed 227400 buildings... 3658 DES, 20527 AFF, 189005 ND
# Processed 227600 buildings... 3658 DES, 20527 AFF, 189205 ND
# Processed 227800 buildings... 3658 DES, 20527 AFF, 189405 ND
# Processed 228000 buildings... 3658 DES, 20527 AFF, 189605 ND
# Processed 228200 buildings... 3658 DES, 20527 AFF, 189805 ND
# Processed 228400 buildings... 3658 DES, 20527 AFF, 190005 ND
# Processed 228600 buildings... 3658 DES, 20527 AFF, 190205 ND
# Processed 228800 buildings... 3658 DES, 20527 AFF, 190405 ND
# Processed 229000 buildings... 3658 DES, 20527 AFF, 190605 ND
# Processed 229200 buildings... 3658 DES, 20527 AFF, 190805 ND
# Processed 229400 buildings... 3658 DES, 20527 AFF, 191005 ND
# Processed 229600 buildings... 3658 DES, 20527 AFF, 191205 ND
# Processed 229800 buildings... 3658 DES, 20527 AFF, 191405 ND
# Processed 230000 buildings... 3658 DES, 20527 AFF, 191605 ND
# Processed 230200 buildings... 3658 DES, 20527 AFF, 191805 ND
# Processed 230400 buildings... 3658 DES, 20527 AFF, 192005 ND
# Processed 230600 buildings... 3658 DES, 20527 AFF, 192205 ND
# Processed 230800 buildings... 3658 DES, 20527 AFF, 192405 ND
# Processed 231000 buildings... 3658 DES, 20527 AFF, 192605 ND
# Processed 231200 buildings... 3658 DES, 20527 AFF, 192805 ND
# Processed 231400 buildings... 3658 DES, 20527 AFF, 193005 ND
# Processed 231600 buildings... 3658 DES, 20527 AFF, 193205 ND
# Processed 231800 buildings... 3658 DES, 20527 AFF, 193405 ND
# Processed 232000 buildings... 3658 DES, 20527 AFF, 193605 ND
# Processed 232200 buildings... 3658 DES, 20527 AFF, 193805 ND
# Processed 232400 buildings... 3658 DES, 20527 AFF, 194005 ND
# Processed 232600 buildings... 3658 DES, 20527 AFF, 194205 ND
# Processed 232800 buildings... 3658 DES, 20527 AFF, 194405 ND
# Processed 233000 buildings... 3658 DES, 20527 AFF, 194605 ND
# Processed 233200 buildings... 3658 DES, 20527 AFF, 194805 ND
# Processed 233400 buildings... 3658 DES, 20527 AFF, 195005 ND
# Processed 233600 buildings... 3658 DES, 20527 AFF, 195205 ND
# Processed 233800 buildings... 3658 DES, 20527 AFF, 195405 ND
# Processed 234000 buildings... 3658 DES, 20527 AFF, 195605 ND
# Processed 234200 buildings... 3658 DES, 20527 AFF, 195805 ND
# Processed 234400 buildings... 3658 DES, 20527 AFF, 196005 ND
# Processed 234600 buildings... 3658 DES, 20527 AFF, 196205 ND
# Processed 234800 buildings... 3658 DES, 20527 AFF, 196405 ND
# Processed 235000 buildings... 3658 DES, 20527 AFF, 196605 ND
# Processed 235200 buildings... 3658 DES, 20527 AFF, 196805 ND
# Processed 235400 buildings... 3658 DES, 20527 AFF, 197005 ND
# Processed 235600 buildings... 3658 DES, 20527 AFF, 197205 ND
# Processed 235800 buildings... 3658 DES, 20527 AFF, 197405 ND
# Processed 236000 buildings... 3658 DES, 20527 AFF, 197605 ND
# Processed 236200 buildings... 3658 DES, 20527 AFF, 197805 ND
# Processed 236400 buildings... 3658 DES, 20527 AFF, 198005 ND
# Processed 236600 buildings... 3658 DES, 20527 AFF, 198205 ND
# Processed 236800 buildings... 3658 DES, 20527 AFF, 198405 ND
# Processed 237000 buildings... 3658 DES, 20527 AFF, 198605 ND
# Processed 237200 buildings... 3658 DES, 20527 AFF, 198805 ND
# Processed 237400 buildings... 3658 DES, 20527 AFF, 199005 ND
# Processed 237600 buildings... 3658 DES, 20527 AFF, 199205 ND
# Processed 237800 buildings... 3658 DES, 20527 AFF, 199405 ND
# Processed 238000 buildings... 3658 DES, 20527 AFF, 199605 ND
# Processed 238200 buildings... 3658 DES, 20527 AFF, 199805 ND
# Processed 238400 buildings... 3658 DES, 20527 AFF, 200005 ND
# Processed 238600 buildings... 3658 DES, 20527 AFF, 200205 ND
# Processed 238800 buildings... 3658 DES, 20527 AFF, 200405 ND
# Processed 239000 buildings... 3658 DES, 20527 AFF, 200605 ND
# Processed 239200 buildings... 3658 DES, 20527 AFF, 200805 ND
# Processed 239400 buildings... 3658 DES, 20527 AFF, 201005 ND
# Processed 239600 buildings... 3658 DES, 20527 AFF, 201205 ND
# Processed 239800 buildings... 3658 DES, 20527 AFF, 201405 ND
# Processed 240000 buildings... 3658 DES, 20527 AFF, 201605 ND
# Processed 240200 buildings... 3658 DES, 20527 AFF, 201805 ND
# Processed 240256 buildings

# %%
# Split out onto a smaller dataset to test out transfer learning. 
import numpy as np
import os

from random import shuffle

ORIG_BASE_DIR = '/Users/apando/school/cs230/project/datasets/hurricane_maria/building_crops_noaa_rezoom/'
TRIM_BASE_DIR = '/Users/apando/school/cs230/project/datasets/hurricane_maria/building_crops_noaa_rezoom_sample/'

# Add to train set
train_coords = set()
for c in ('damaged/', 'non_damaged/'):
    all_images = np.array(os.listdir(ORIG_BASE_DIR + c))
    print("Num {0} images to process: {1}".format(c, str(len(all_images))))
    img_idx = list(range(len(all_images)))
    shuffle(img_idx)
    print(img_idx[0:5])
    num_processed = 0
    for i in img_idx[0:2000]:
        os.system("cp {0} {1}".format(ORIG_BASE_DIR + c + all_images[i], TRIM_BASE_DIR + 'train/' + c + all_images[i]))
        train_coords.add(all_images[i].split('_')[0])
        num_processed += 1
        if num_processed % 500 == 0:
            print("Processed {0} {1} images...".format(num_processed, c))
    print("Copied {0} {1} images total".format(num_processed, c))
    
# Add to validation set
validate_coords = set()
for c in ('damaged/', 'non_damaged/'):
    all_images = np.array(os.listdir(ORIG_BASE_DIR + c))
    img_idx = list(range(len(all_images)))
    shuffle(img_idx)
    print(img_idx[0:5])
    i = 0
    num_processed = 0
    while num_processed < 400:
        curr_fname = all_images[img_idx[i]]
        curr_bldg = curr_fname.split('_')[0]
        if curr_bldg in train_coords:
            # Skip the building, even if it's not in the same tile as in training.
            i += 1
            continue
        os.system("cp {0} {1}".format(ORIG_BASE_DIR + c + curr_fname, TRIM_BASE_DIR + 'validation/' + c + curr_fname))
        validate_coords.add(curr_bldg)
        num_processed += 1
        i += 1
        if num_processed % 100 == 0:
            print("Processed {0} {1} images...".format(num_processed, c))
    print("Copied {0} {1} validation images total".format(num_processed, c))
    print("Iterated thru {0} {1} images total".format(i, c))
    
# Add to test set
for c in ('damaged/', 'non_damaged/'):
    all_images = np.array(os.listdir(ORIG_BASE_DIR + c))
    img_idx = list(range(len(all_images)))
    shuffle(img_idx)
    print(img_idx[0:5])
    i = 0
    num_processed = 0
    while num_processed < 400:
        curr_fname = all_images[img_idx[i]]
        curr_bldg = curr_fname.split('_')[0]
        if (curr_bldg in train_coords) or (curr_bldg in validate_coords):
            # Skip the building, even if it's not in the same tile as in training.
            i += 1
            continue
        os.system("cp {0} {1}".format(ORIG_BASE_DIR + c + curr_fname, TRIM_BASE_DIR + 'test/' + c + curr_fname))
        num_processed += 1
        i += 1
        if num_processed % 100 == 0:
            print("Processed {0} {1} images...".format(num_processed, c))
    print("Copied {0} {1} test images total".format(num_processed, c))
    print("Iterated thru {0} {1} images total".format(i, c))
# Out:
# Num damaged/ images to process: 37067
# [21963, 18604, 19656, 24701, 26730]
# Processed 500 damaged/ images...
# Processed 1000 damaged/ images...
# Processed 1500 damaged/ images...
# Processed 2000 damaged/ images...
# Copied 2000 damaged/ images total
# Num non_damaged/ images to process: 201857
# [141618, 16894, 54440, 42761, 123981]
# Processed 500 non_damaged/ images...
# Processed 1000 non_damaged/ images...
# Processed 1500 non_damaged/ images...
# Processed 2000 non_damaged/ images...
# Copied 2000 non_damaged/ images total
# [36644, 9940, 4027, 18738, 7980]
# Processed 100 damaged/ images...
# Processed 200 damaged/ images...
# Processed 300 damaged/ images...
# Processed 400 damaged/ images...
# Copied 400 damaged/ validation images total
# Iterated thru 428 damaged/ images total
# [193535, 153473, 121484, 176217, 61194]
# Processed 100 non_damaged/ images...
# Processed 200 non_damaged/ images...
# Processed 300 non_damaged/ images...
# Processed 400 non_damaged/ images...
# Copied 400 non_damaged/ validation images total
# Iterated thru 404 non_damaged/ images total
# [15884, 2197, 28276, 33090, 6630]
# Processed 100 damaged/ images...
# Processed 200 damaged/ images...
# Processed 300 damaged/ images...
# Processed 400 damaged/ images...
# Copied 400 damaged/ test images total
# Iterated thru 438 damaged/ images total
# [60740, 187229, 147615, 70553, 138847]
# Processed 100 non_damaged/ images...
# Processed 200 non_damaged/ images...
# Processed 300 non_damaged/ images...
# Processed 400 non_damaged/ images...
# Copied 400 non_damaged/ test images total
# Iterated thru 406 non_damaged/ images total

# %%
# Isolate a 'destroyed' dataset
import numpy as np
import os

from random import shuffle

ORIG_BASE_DIR = '/Users/apando/school/cs230/project/datasets/hurricane_maria/building_crops_noaa_rezoom/'
TRIM_BASE_DIR = '/Users/apando/school/cs230/project/datasets/hurricane_maria/building_crops_noaa_rezoom_des/'

# Add to train set
train_coords = set()
for c in ('damaged/', 'non_damaged/'):
    all_images = np.array(os.listdir(ORIG_BASE_DIR + c))
    print("Num {0} images to process: {1}".format(c, str(len(all_images))))
    img_idx = list(range(len(all_images)))
    shuffle(img_idx)
    print(img_idx[0:5])
    i = 0
    num_processed = 0
    while num_processed < 2000:
        if (c == 'damaged/') and not all_images[img_idx[i]].split('.')[-2].endswith('des'):
            i += 1
            continue
        os.system("cp {0} {1}".format(ORIG_BASE_DIR + c + all_images[img_idx[i]], TRIM_BASE_DIR + 'train/' + c + all_images[i]))
        train_coords.add(all_images[img_idx[i]].split('_')[0])
        i += 1
        num_processed += 1
        if num_processed % 500 == 0:
            print("Processed {0} {1} images...".format(num_processed, c))
    print("Copied {0} {1} images total".format(num_processed, c))
    
# Add to validation set
validate_coords = set()
for c in ('damaged/', 'non_damaged/'):
    all_images = np.array(os.listdir(ORIG_BASE_DIR + c))
    img_idx = list(range(len(all_images)))
    shuffle(img_idx)
    print(img_idx[0:5])
    i = 0
    num_processed = 0
    while num_processed < 400:
        curr_fname = all_images[img_idx[i]]
        curr_bldg = curr_fname.split('_')[0]
        if (curr_bldg in train_coords) or ((c == 'damaged/') and not all_images[img_idx[i]].split('.')[-2].endswith('des')):
            # Skip the building, even if it's not in the same tile as in training.
            i += 1
            continue
        os.system("cp {0} {1}".format(ORIG_BASE_DIR + c + curr_fname, TRIM_BASE_DIR + 'validation/' + c + curr_fname))
        validate_coords.add(curr_bldg)
        num_processed += 1
        i += 1
        if num_processed % 50 == 0:
            print("Processed {0} {1} images...".format(num_processed, c))
    print("Copied {0} {1} validation images total".format(num_processed, c))
    print("Iterated thru {0} {1} images total".format(i, c))
    
# Add to test set
for c in ('damaged/', 'non_damaged/'):
    all_images = np.array(os.listdir(ORIG_BASE_DIR + c))
    img_idx = list(range(len(all_images)))
    shuffle(img_idx)
    print(img_idx[0:5])
    i = 0
    num_processed = 0
    while num_processed < 400:
        curr_fname = all_images[img_idx[i]]
        curr_bldg = curr_fname.split('_')[0]
        if (curr_bldg in train_coords) or (curr_bldg in validate_coords) or ((c == 'damaged/') and not all_images[img_idx[i]].split('.')[-2].endswith('des')):
            # Skip the building, even if it's not in the same tile as in training.
            i += 1
            continue
        os.system("cp {0} {1}".format(ORIG_BASE_DIR + c + curr_fname, TRIM_BASE_DIR + 'test/' + c + curr_fname))
        num_processed += 1
        i += 1
        if num_processed % 50 == 0:
            print("Processed {0} {1} images...".format(num_processed, c))
    print("Copied {0} {1} test images total".format(num_processed, c))
    print("Iterated thru {0} {1} images total".format(i, c))
# Out:
# Num damaged/ images to process: 37067
# [19029, 23961, 3797, 30136, 13099]
# Processed 500 damaged/ images...
# Processed 1000 damaged/ images...
# Processed 1500 damaged/ images...
# Processed 2000 damaged/ images...
# Copied 2000 damaged/ images total
# Num non_damaged/ images to process: 201857
# [178788, 170730, 162964, 103382, 24730]
# Processed 500 non_damaged/ images...
# Processed 1000 non_damaged/ images...
# Processed 1500 non_damaged/ images...
# Processed 2000 non_damaged/ images...
# Copied 2000 non_damaged/ images total
# [23510, 827, 36754, 36233, 23880]
# Processed 50 damaged/ images...
# Processed 100 damaged/ images...
# Processed 150 damaged/ images...
# Processed 200 damaged/ images...
# Processed 250 damaged/ images...
# Processed 300 damaged/ images...
# Processed 350 damaged/ images...
# Processed 400 damaged/ images...
# Copied 400 damaged/ validation images total
# Iterated thru 10302 damaged/ images total
# [36225, 130597, 127087, 161142, 197320]
# Processed 50 non_damaged/ images...
# Processed 100 non_damaged/ images...
# Processed 150 non_damaged/ images...
# Processed 200 non_damaged/ images...
# Processed 250 non_damaged/ images...
# Processed 300 non_damaged/ images...
# Processed 350 non_damaged/ images...
# Processed 400 non_damaged/ images...
# Copied 400 non_damaged/ validation images total
# Iterated thru 402 non_damaged/ images total
# [24197, 5043, 27187, 17494, 32952]
# Processed 50 damaged/ images...
# Processed 100 damaged/ images...
# Processed 150 damaged/ images...
# Processed 200 damaged/ images...
# Processed 250 damaged/ images...
# Processed 300 damaged/ images...
# Processed 350 damaged/ images...
# Processed 400 damaged/ images...
# Copied 400 damaged/ test images total
# Iterated thru 13916 damaged/ images total
# [25951, 147006, 131868, 135111, 36874]
# Processed 50 non_damaged/ images...
# Processed 100 non_damaged/ images...
# Processed 150 non_damaged/ images...
# Processed 200 non_damaged/ images...
# Processed 250 non_damaged/ images...
# Processed 300 non_damaged/ images...
# Processed 350 non_damaged/ images...
# Processed 400 non_damaged/ images...
# Copied 400 non_damaged/ test images total
# Iterated thru 401 non_damaged/ images total

# %%
# Get more train/test/validation data
# Isolate a 'destroyed' dataset
import numpy as np
import os

from random import shuffle

ORIG_BASE_DIR = '/Users/apando/school/cs230/project/datasets/hurricane_maria/building_crops_noaa_rezoom/'
TRIM_BASE_DIR = '/Users/apando/school/cs230/project/datasets/hurricane_maria/building_crops_noaa_rezoom_des/'
BAD_BASE_DIR = '/Users/apando/school/cs230/project/datasets/hurricane_maria/trash/'
ADD_BASE_DIR = '/Users/apando/school/cs230/project/datasets/hurricane_maria/building_crops_noaa_rezoom_des_more/'


# Add to train set
train_coords = set()
#for c in ('damaged/', 'non_damaged/'):
for c in ('damaged/',):
    all_images = np.array(os.listdir(ORIG_BASE_DIR + c))
    print("Num {0} images to process: {1}".format(c, str(len(all_images))))
    
    existing_coords = set([x.split('_')[0] for x in os.listdir(TRIM_BASE_DIR + 'train/' + c)])
    existing_coords = existing_coords.union(set([x.split('_')[0] for x in os.listdir(TRIM_BASE_DIR + 'validation/' + c)]))
    existing_coords = existing_coords.union(set([x.split('_')[0] for x in os.listdir(TRIM_BASE_DIR + 'test/' + c)]))
    print("Num {0} existing images: {1}".format(c, str(len(existing_coords))))
    
    bad_coords = set([x.split('_')[0] for x in os.listdir(BAD_BASE_DIR)])
    print("Num bad images: {}".format(str(len(bad_coords))))
    
    img_idx = list(range(len(all_images)))
    shuffle(img_idx)
    print(img_idx[0:5])
    i = 0
    num_processed = 0
    while num_processed < 2000:
        curr_fname = all_images[img_idx[i]]
        curr_bldg = curr_fname.split('_')[0]
        if (curr_bldg in existing_coords) or (curr_bldg in bad_coords) or ((c == 'damaged/') and not all_images[img_idx[i]].split('.')[-2].endswith('des')):
            i += 1
            continue
        os.system("cp {0} {1}".format(ORIG_BASE_DIR + c + curr_fname, ADD_BASE_DIR + 'train/' + c + curr_fname))
        train_coords.add(curr_bldg)
        i += 1
        num_processed += 1
        if num_processed % 500 == 0:
            print("Processed {0} {1} images...".format(num_processed, c))
    print("Copied {0} {1} images total".format(num_processed, c))
# Out:
# Num damaged/ images to process: 37067
# Num damaged/ existing images: 1395
# Num bad images: 2095
# [8072, 4799, 24004, 12322, 28622]
# Processed 500 damaged/ images...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-bd24cd4db9a7> in <module>
#      33     num_processed = 0
#      34     while num_processed < 2000:
# ---> 35         curr_fname = all_images[img_idx[i]]
#      36         curr_bldg = curr_fname.split('_')[0]
#      37         if (curr_bldg in existing_coords) or (curr_bldg in bad_coords) or ((c == 'damaged/') and not all_images[img_idx[i]].split('.')[-2].endswith('des')):
#
# IndexError: list index out of range

# %%
# Get more train/test/validation data
# Isolate a 'destroyed' dataset
import numpy as np
import os

from random import shuffle

ORIG_BASE_DIR = '/Users/apando/school/cs230/project/datasets/hurricane_maria/building_crops_noaa_rezoom_des/train/'
TRIM_BASE_DIR = '/Users/apando/school/cs230/project/datasets/hurricane_maria/building_crops_noaa_rezoom_des_balanced/'

# Add to train set
train_coords = set()
#for c in ('damaged/', 'non_damaged/'):
for c in ('non_damaged/',):
    all_images = np.array(os.listdir(ORIG_BASE_DIR + c))
    print("Num {0} images to process: {1}".format(c, str(len(all_images))))
   
    img_idx = list(range(len(all_images)))
    shuffle(img_idx)
    print(img_idx[0:5])
    i = 0
    num_processed = 0
    while num_processed < 1000:
        curr_fname = all_images[img_idx[i]]
        curr_bldg = curr_fname.split('_')[0]
        os.system("cp {0} {1}".format(ORIG_BASE_DIR + c + curr_fname, TRIM_BASE_DIR + 'train/' + c + curr_fname))
        train_coords.add(curr_bldg)
        i += 1
        num_processed += 1
        if num_processed % 200 == 0:
            print("Processed {0} {1} images...".format(num_processed, c))
    print("Copied {0} {1} images total".format(num_processed, c))
# Out:
# Num non_damaged/ images to process: 1412
# [712, 768, 1159, 1163, 517]
# Processed 200 non_damaged/ images...
# Processed 400 non_damaged/ images...
# Processed 600 non_damaged/ images...
# Processed 800 non_damaged/ images...
# Processed 1000 non_damaged/ images...
# Copied 1000 non_damaged/ images total
